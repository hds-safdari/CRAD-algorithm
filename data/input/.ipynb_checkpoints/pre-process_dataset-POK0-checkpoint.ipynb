# %% [markdown]
# ### Pre-process datasets
# Goal : make input files suitable for the algorithm.

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# import wget

# %%
# %matplotlib notebook

# %%
def reciprocal_edges(G):
    N=G.number_of_nodes()
    nodes=list(G.nodes())
    edges=G.edges()
    unique_edges=[]
    reciprocal_list=[]
    for idxi in range(N):
        i=nodes[idxi]
        for idxj in range(idxi+1,N):
            j=nodes[idxj]
            if (i,j) in edges or (j,i) in edges: 
                unique_edges.append((i,j))
                if (i,j) in edges and (j,i) in edges: 
                    reciprocal_list.append((i,j))

    unique_edges = list(set(unique_edges))
    reciprocal = len(reciprocal_list)
 
    print("reciprocal:", reciprocal,len(unique_edges),"reciprocity:",reciprocal/float(len(unique_edges)),reciprocal/float(len(unique_edges)+reciprocal)) 
    return  unique_edges, reciprocal_list

# %%
# !pwd
# Out:
# /Users/hsafdari/Dropbox/Dr_Caterina_de_Bacco/anomaly detection/data/input

# %%
# !ls
# Out:
# RD                              pre-process_dataset.ipynb
# data_description.md             pre-process_facebookwaall.ipynb
# dutch2.dat                      syn_500_3_20.0_0.8_True_0.dat
# dutch6.dat                      synthetic
# facebook-wosn-wall.dat          theta_500_3_20.0_0.8_True_0.npz
# pok_month0.dat                  twitter.dat
# pre-process_WikiTalkht.ipynb    wiki_talk_ht.dat
# pre-process_dataset-POK0.ipynb

# %%
outnet='pok_month0'
input_data = pd.read_csv(outnet+'.dat', skiprows=[0], header=None, sep='\s+')

# %%
df = pd.DataFrame(input_data)
df.head(n=2)
# Out:
#    0  1  2
# 0  0  1  4
# 1  0  2  1

# %%
df[2] = 1
df.head(2)
# Out:
#    0  1  2
# 0  0  1  1
# 1  0  2  1

# %% [markdown]
# ### Remove 'E' from first column

# %%
# df=df.drop(0,axis=1)
# df.columns=[0,1,2]

# %%
df.head(n=2)
# Out:
#    0  1  2
# 0  0  1  1
# 1  0  2  1

# %%
df[2].unique()
# Out:
# array([1])

# %%
len(df)
# Out:
# 18098

# %% [markdown]
# ### Keep only some of the edges, based on the third column.
# For POK dataset, keep only one month of data.

# %%
# onemonth = 60*60*24*30
# df=input_data[input_data[2]<onemonth]
# len(df)

# %% [markdown]
# ### Keep only nodes that have at least one incoming and one outgoing edge

# %%
# ego=input_data[0].unique()
# alter=input_data[1].unique()
# df=input_data[input_data[0].isin(nodes)]

ego=df[0].unique()
alter=df[1].unique()
nodes = set(ego).intersection(set(alter))
print(len(nodes))

df=df[df[0].isin(nodes)]
df=df[df[1].isin(nodes)]
len(df)
# Out:
# 3504
# 18026

# %% [markdown]
# ### Build multigraph

# %%
edge_list=[(n[0],n[1],len(g)) for n,g in df.groupby(by=[0,1])]

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from(edge_list) # or G.add_edges_from(edge_list)

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from(df.values)

# %%
list(G.edges(data=True))[:5]
# Out:
# [(0, 1, {'weight': 1}),
#  (0, 2, {'weight': 1}),
#  (0, 3, {'weight': 1}),
#  (0, 6, {'weight': 1}),
#  (0, 7, {'weight': 1})]

# %% [markdown]
# ### Remove self loops

# %%
G.remove_edges_from(list(nx.selfloop_edges(G)))
G.number_of_nodes(),G.number_of_edges()
# Out:
# (3504, 18026)

# %%
G.out_degree()
# Out:
# OutMultiDegreeView({0: 10, 1: 39, 2: 47, 3: 63, 6: 31, 7: 6, 9: 77, 10: 4, 14: 2, 72: 3, 492: 11, 5: 20, 27: 6, 34: 4, 47: 11, 65: 16, 77: 8, 78: 10, 84: 5, 94: 13, 104: 5, 117: 3, 127: 25, 130: 4, 134: 8, 144: 27, 174: 3, 181: 4, 184: 3, 395: 14, 566: 14, 567: 9, 702: 9, 829: 30, 960: 21, 990: 5, 1797: 6, 2020: 1, 2271: 15, 2282: 2, 2296: 2, 2308: 2, 2581: 4, 3256: 9, 4195: 2, 4: 402, 8: 9, 13: 6, 15: 13, 17: 18, 19: 3, 22: 4, 40: 10, 52: 7, 54: 10, 55: 23, 56: 6, 57: 11, 58: 11, 62: 61, 66: 9, 75: 10, 76: 3, 91: 2, 99: 1, 123: 10, 128: 6, 143: 30, 183: 16, 342: 31, 374: 17, 453: 2, 497: 7, 498: 7, 862: 9, 965: 19, 973: 27, 980: 5, 1890: 4, 2139: 15, 2785: 10, 3747: 71, 16: 8, 87: 2, 115: 1, 131: 9, 177: 23, 199: 4, 230: 2, 451: 3, 525: 4, 591: 11, 601: 7, 682: 9, 773: 15, 840: 2, 971: 5, 988: 41, 1045: 2, 1070: 8, 1658: 13, 1997: 3, 2021: 2, 2052: 3, 2630: 4, 2660: 29, 2689: 2, 2887: 6, 3836: 4, 5279: 12, 59: 3, 64: 7, 100: 14, 135: 3, 293: 6, 454: 1, 1459: 23, 2379: 1, 2407: 1, 2663: 3, 3188: 39, 4146: 4, 4456: 38, 4616: 2, 5137: 2, 5148: 1, 12: 1, 21: 2, 24: 3, 25: 1, 26: 1, 35: 7, 51: 1, 61: 17, 71: 33, 83: 1, 106: 40, 149: 4, 154: 4, 191: 16, 197: 3, 204: 1, 265: 1, 385: 34, 409: 13, 513: 2, 877: 5, 883: 9, 885: 56, 945: 20, 1007: 4, 1052: 3, 1152: 6, 1153: 6, 1155: 3, 1161: 12, 1168: 9, 1336: 11, 1341: 1, 1346: 2, 1468: 1, 1516: 3, 1798: 8, 1811: 18, 1831: 5, 1847: 12, 2002: 1, 2159: 1, 2205: 1, 2305: 15, 2564: 1, 2850: 14, 2857: 11, 3038: 1, 3159: 13, 3262: 2, 3328: 2, 3655: 3, 2466: 2, 2675: 33, 295: 9, 502: 26, 572: 2, 719: 1, 999: 10, 1253: 7, 1283: 3, 1558: 14, 2418: 1, 11: 2, 290: 10, 686: 3, 1063: 29, 1236: 38, 73: 4, 364: 74, 367: 63, 122: 14, 80: 4, 891: 20, 3070: 3, 3240: 40, 3626: 29, 4095: 14, 4140: 16, 4339: 27, 4496: 6, 4500: 8, 4770: 8, 5059: 29, 5103: 9, 107: 2, 2012: 24, 3584: 3, 983: 8, 1773: 30, 1949: 45, 2075: 13, 2501: 5, 2591: 3, 2999: 27, 3428: 24, 3505: 23, 178: 9, 1933: 8, 2383: 9, 171: 1, 182: 13, 272: 1, 278: 7, 396: 24, 411: 31, 781: 13, 827: 5, 854: 58, 1021: 2, 1753: 6, 1791: 20, 2771: 6, 3101: 50, 3559: 6, 3706: 22, 3789: 10, 4678: 7, 480: 18, 1018: 3, 2083: 30, 2653: 3, 289: 13, 373: 10, 884: 42, 326: 39, 1687: 12, 346: 17, 2442: 26, 4246: 11, 4491: 7, 4512: 2, 4921: 4, 292: 14, 2006: 37, 2128: 8, 2644: 11, 2651: 4, 2781: 1, 3126: 9, 3191: 13, 3648: 24, 328: 12, 785: 12, 821: 3, 2095: 15, 2184: 20, 5336: 1, 735: 6, 3135: 1, 68: 15, 286: 12, 334: 26, 946: 2, 1068: 3, 1121: 23, 1987: 38, 2228: 2, 2400: 13, 2419: 12, 2508: 16, 2608: 6, 2681: 1, 2684: 1, 2692: 9, 2996: 5, 3082: 23, 3682: 21, 4011: 5, 279: 12, 969: 1, 970: 2, 979: 3, 993: 1, 1375: 32, 1455: 33, 3239: 8, 752: 67, 3063: 2, 766: 19, 2259: 10, 2272: 19, 2460: 4, 2676: 5, 3536: 3, 3775: 11, 5371: 3, 2989: 13, 3735: 39, 4890: 3, 2566: 9, 2570: 26, 2805: 5, 1637: 44, 1993: 13, 3595: 6, 3624: 38, 4080: 10, 4961: 28, 3274: 13, 23: 7, 37: 4, 39: 1, 105: 12, 111: 3, 119: 3, 120: 3, 147: 2, 172: 2, 173: 2, 203: 1, 231: 1, 255: 4, 257: 1, 258: 1, 304: 7, 327: 1, 329: 1, 335: 1, 343: 1, 355: 3, 357: 1, 381: 3, 387: 1, 401: 3, 416: 3, 436: 1, 439: 1, 441: 3, 442: 3, 488: 9, 504: 1, 512: 1, 517: 4, 527: 2, 528: 2, 529: 4, 543: 2, 544: 11, 586: 8, 594: 10, 604: 9, 606: 1, 622: 1, 625: 1, 634: 13, 639: 10, 648: 1, 659: 3, 665: 6, 669: 13, 680: 1, 681: 1, 685: 2, 699: 5, 718: 2, 723: 1, 725: 2, 770: 7, 782: 1, 789: 1, 795: 1, 813: 2, 822: 1, 833: 4, 842: 6, 855: 1, 857: 1, 869: 9, 870: 2, 873: 1, 876: 2, 889: 5, 933: 2, 958: 14, 959: 9, 984: 4, 1000: 4, 1003: 1, 1011: 2, 1028: 1, 1039: 4, 1054: 3, 1079: 6, 1080: 3, 1119: 3, 1126: 8, 1130: 12, 1177: 3, 1187: 14, 1201: 2, 1206: 2, 1214: 6, 1288: 17, 1317: 6, 1321: 4, 1331: 1, 1335: 7, 1337: 11, 1345: 3, 1365: 7, 1370: 7, 1383: 1, 1385: 2, 1394: 1, 1395: 1, 1451: 6, 1467: 3, 1480: 1, 1503: 2, 1504: 1, 1528: 1, 1533: 3, 1538: 11, 1552: 5, 1553: 2, 1563: 3, 1567: 2, 1571: 3, 1581: 4, 1608: 3, 1610: 15, 1618: 8, 1631: 2, 1643: 7, 1654: 4, 1684: 10, 1701: 2, 1719: 6, 1728: 3, 1732: 6, 1754: 1, 1758: 9, ...

# %% [markdown]
# ### Remove nodes that have few out- or in-coming edges

# %%
outdegree = [ d[1] for d in list(G.out_degree())]
indegree = [ d[1] for d in list(G.in_degree())]

np.percentile(outdegree,50)
# Out:
# 2.0

# %%
G1=nx.MultiDiGraph(G)

# %%
threshold=0

Gnodes = list(G.nodes())
nodes_to_remove=[n for n in Gnodes if G.out_degree(n)<threshold]
nodes_to_remove.extend([n for n in Gnodes if G.in_degree(n)<threshold])
nodes_to_remove=list(set(nodes_to_remove))
len(nodes_to_remove),len(Gnodes)

G1.remove_nodes_from(list(nodes_to_remove))
print(len(nodes_to_remove))
# Out:
# 0

# %%
G1.number_of_nodes(),G1.number_of_edges()
# Out:
# (3504, 18026)

# %%
ncc = nx.number_weakly_connected_components(G1)
cc = list(nx.weakly_connected_components(G))
for c in range(ncc):
    print(c,len(cc[c]))
# Out:
# 0 3433
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 4
# 7 2
# 8 2
# 9 2
# 10 2
# 11 2
# 12 2
# 13 2
# 14 2
# 15 2
# 16 2
# 17 2
# 18 2
# 19 2
# 20 2
# 21 2
# 22 2
# 23 2
# 24 2
# 25 2
# 26 2
# 27 2
# 28 3
# 29 2
# 30 2
# 31 2
# 32 2
# 33 2
# 34 2

# %%
Gc = max(nx.weakly_connected_components(G1), key=len)
Gc = cc[3]
nodes_to_remove=set(G1.nodes()).difference(Gc)
print("removed" ,len(nodes_to_remove),' nodes')
G1.remove_nodes_from(list(nodes_to_remove))
print(G1.number_of_nodes(),G1.number_of_edges())
# Out:
# removed 3502  nodes
# 2 2

# %%
unique_edges, reciprocal_list = reciprocal_edges(G1)
# Out:
# reciprocal: 7052 10974 reciprocity: 0.6426098049936213 0.39121269277709975

# %%
G1nodes = list(G1.nodes())
pos = nx.spring_layout(G1)

# %%
# subG = np.random.choice(G1nodes,400)
# k = G1.subgraph(subG)  
k =G1

plt.figure()
nx.draw_networkx(k, pos=pos,with_labels=False,node_size=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# nx.draw(G1)

# %% [markdown]
# ### Output on file

# %%
outfile = 'RD/'+outnet+'.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
nx.write_weighted_edgelist(G, outfile)
print(outfile)
# Out:
# RD/pok_month0.dat
