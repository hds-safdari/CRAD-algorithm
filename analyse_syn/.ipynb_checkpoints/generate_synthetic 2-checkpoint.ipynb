# %% [markdown]
# Notebook used to generate synthetic networks by using two different generative models: ReciprocityMMSBM_conditionals and ReciprocityMMSBM_joints. <br>In particular, here, we generate networks by varying the eta parameter.

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
import synthetic

# %% [markdown]
# #### ReciprocityMMSBM_conditionals

# %%
avg_degree = 20
out_folder = f'../../data/input/ReciprocityMMSBM_conditionals_{avg_degree}/'
show_details = True
show_plots = False

np.random.seed(17)
rseed = np.random.randint(18)

# %%
for eta in [0., 0.1, 0.2, 0.35, 0.45, 0.6, 0.75, 0.9, 0.999]:
    for _ in range(10):
        synthetic.ReciprocityMMSBM_conditionals(avg_degree=avg_degree, eta=eta, seed=rseed, out_folder=out_folder, 
                                                show_details=show_details, show_plots=show_plots)
        rseed += np.random.randint(1,18)
        print('\n')
# Out:
# ../synthetic.py:349: UserWarning: is_sparse parameter was not set. Defaulting to is_sparse=True
#   warnings.warn(msg)
# ../synthetic.py:358: UserWarning: label parameter was not set. Defaulting to label=_N_L_K_avgdegree_eta_seed
#   warnings.warn(msg)
# ../synthetic.py:377: UserWarning: perc_overlapping parameter was not set. Defaulting to perc_overlapping=0.2
#   warnings.warn(msg)
# ../synthetic.py:391: UserWarning: correlation_u_v parameter for overlapping communities was not set. Defaulting to corr=0.0
#   warnings.warn(msg)
# ../synthetic.py:399: UserWarning: alpha parameter of Dirichlet distribution was not set. Defaulting to alpha=[0.1, 0.1]
#   warnings.warn(msg)
# ../synthetic.py:422: UserWarning: structure parameter was not set. Defaulting to structure=['assortative']
#   warnings.warn(msg)
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_15.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_15.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9854 - <k> = 19.708
# M[0] = 9930 - <k_weighted> = 19.86
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.017
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.008
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_31.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_31.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9847 - <k> = 19.694
# M[0] = 9927 - <k_weighted> = 19.854
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.016
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.008
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_38.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_38.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9991 - <k> = 19.982
# M[0] = 10066 - <k_weighted> = 20.132
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.014
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.007
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_55.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_55.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9912 - <k> = 19.824
# M[0] = 10011 - <k_weighted> = 20.022
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.013
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.006
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_69.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_69.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10043 - <k> = 20.086
# M[0] = 10138 - <k_weighted> = 20.276
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.015
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.007
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_74.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_74.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10101 - <k> = 20.202
# M[0] = 10192 - <k_weighted> = 20.384
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.015
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.008
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_82.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_82.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9682 - <k> = 19.364
# M[0] = 9757 - <k_weighted> = 19.514
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.014
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.007
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_95.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_95.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9942 - <k> = 19.884
# M[0] = 10024 - <k_weighted> = 20.048
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.015
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.008
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_103.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_103.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9927 - <k> = 19.854
# M[0] = 10006 - <k_weighted> = 20.012
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.014
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.007
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.0_105.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.0_105.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9904 - <k> = 19.808
# M[0] = 9997 - <k_weighted> = 19.994
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.015
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.007
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_120.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_120.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9894 - <k> = 19.788
# M[0] = 10002 - <k_weighted> = 20.004
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.106
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.056
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_130.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_130.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9927 - <k> = 19.854
# M[0] = 10036 - <k_weighted> = 20.072
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.11
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.058
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_141.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_141.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9750 - <k> = 19.5
# M[0] = 9835 - <k_weighted> = 19.67
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.105
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.055
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_144.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_144.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9803 - <k> = 19.606
# M[0] = 9921 - <k_weighted> = 19.842
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.113
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.06
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_148.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_148.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9849 - <k> = 19.698
# M[0] = 9954 - <k_weighted> = 19.908
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.113
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.06
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_155.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_155.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9917 - <k> = 19.834
# M[0] = 10034 - <k_weighted> = 20.068
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.111
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.059
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_162.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_162.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10087 - <k> = 20.174
# M[0] = 10196 - <k_weighted> = 20.392
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.118
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.063
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_172.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_172.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9836 - <k> = 19.672
# M[0] = 9956 - <k_weighted> = 19.912
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.112
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.059
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_187.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_187.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9863 - <k> = 19.726
# M[0] = 9980 - <k_weighted> = 19.96
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.11
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.058
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.1_201.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.1_201.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9963 - <k> = 19.926
# M[0] = 10045 - <k_weighted> = 20.09
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.101
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.053
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_207.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_207.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9894 - <k> = 19.788
# M[0] = 10063 - <k_weighted> = 20.126
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.191
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.105
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_208.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_208.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9924 - <k> = 19.848
# M[0] = 10084 - <k_weighted> = 20.168
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.194
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.107
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_214.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_214.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9725 - <k> = 19.45
# M[0] = 9905 - <k_weighted> = 19.81
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.198
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.11
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_221.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_221.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9640 - <k> = 19.28
# M[0] = 9823 - <k_weighted> = 19.646
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.185
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.102
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_228.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_228.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9646 - <k> = 19.292
# M[0] = 9812 - <k_weighted> = 19.624
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.193
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.107
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_231.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_231.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9903 - <k> = 19.806
# M[0] = 10080 - <k_weighted> = 20.16
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.198
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.11
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_244.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_244.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9914 - <k> = 19.828
# M[0] = 10085 - <k_weighted> = 20.17
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.202
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.112
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_258.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_258.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9840 - <k> = 19.68
# M[0] = 9998 - <k_weighted> = 19.996
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.186
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.102
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_269.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_269.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9621 - <k> = 19.242
# M[0] = 9786 - <k_weighted> = 19.572
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.195
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.108
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.2_278.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.2_278.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9720 - <k> = 19.44
# M[0] = 9873 - <k_weighted> = 19.746
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.187
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.103
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_290.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_290.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9606 - <k> = 19.212
# M[0] = 9972 - <k_weighted> = 19.944
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.321
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.191
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_306.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_306.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9713 - <k> = 19.426
# M[0] = 10078 - <k_weighted> = 20.156
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.316
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.187
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_321.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_321.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9696 - <k> = 19.392
# M[0] = 10028 - <k_weighted> = 20.056
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.317
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.188
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_332.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_332.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9775 - <k> = 19.55
# M[0] = 10125 - <k_weighted> = 20.25
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.316
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.187
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_335.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_335.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9540 - <k> = 19.08
# M[0] = 9907 - <k_weighted> = 19.814
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.305
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.18
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_344.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_344.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9550 - <k> = 19.1
# M[0] = 9868 - <k_weighted> = 19.736
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.318
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.189
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_345.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_345.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9601 - <k> = 19.202
# M[0] = 9953 - <k_weighted> = 19.906
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.319
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.19
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_358.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_358.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9713 - <k> = 19.426
# M[0] = 10060 - <k_weighted> = 20.12
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.32
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.19
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_374.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_374.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9846 - <k> = 19.692
# M[0] = 10201 - <k_weighted> = 20.402
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.314
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.186
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.35_379.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.35_379.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9720 - <k> = 19.44
# M[0] = 10090 - <k_weighted> = 20.18
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.306
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.181
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_384.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_384.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9632 - <k> = 19.264
# M[0] = 10133 - <k_weighted> = 20.266
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.388
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.241
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_388.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_388.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9336 - <k> = 18.672
# M[0] = 9794 - <k_weighted> = 19.588
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.388
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.241
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_402.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_402.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9419 - <k> = 18.838
# M[0] = 9893 - <k_weighted> = 19.786
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.381
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.236
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_410.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_410.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9509 - <k> = 19.018
# M[0] = 10051 - <k_weighted> = 20.102
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.383
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.237
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_419.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_419.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9555 - <k> = 19.11
# M[0] = 10066 - <k_weighted> = 20.132
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.386
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.239
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_432.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_432.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9397 - <k> = 18.794
# M[0] = 9928 - <k_weighted> = 19.856
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.38
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.235
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_444.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_444.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9490 - <k> = 18.98
# M[0] = 10004 - <k_weighted> = 20.008
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.383
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.237
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_448.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_448.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9495 - <k> = 18.99
# M[0] = 10017 - <k_weighted> = 20.034
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.387
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.24
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_459.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_459.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9381 - <k> = 18.762
# M[0] = 9897 - <k_weighted> = 19.794
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.39
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.242
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.45_463.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.45_463.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9455 - <k> = 18.91
# M[0] = 9928 - <k_weighted> = 19.856
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.385
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.239
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_465.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_465.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9363 - <k> = 18.726
# M[0] = 10213 - <k_weighted> = 20.426
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.5
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.333
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_481.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_481.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9290 - <k> = 18.58
# M[0] = 10165 - <k_weighted> = 20.33
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.491
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.326
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_495.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_495.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9218 - <k> = 18.436
# M[0] = 10015 - <k_weighted> = 20.03
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.503
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.336
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_502.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_502.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9190 - <k> = 18.38
# M[0] = 9981 - <k_weighted> = 19.962
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.486
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.321
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_516.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_516.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9042 - <k> = 18.084
# M[0] = 9794 - <k_weighted> = 19.588
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.489
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.323
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_531.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_531.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9209 - <k> = 18.418
# M[0] = 10019 - <k_weighted> = 20.038
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.5
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.333
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_533.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_533.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9195 - <k> = 18.39
# M[0] = 9990 - <k_weighted> = 19.98
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.488
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.323
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_548.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_548.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9323 - <k> = 18.646
# M[0] = 10159 - <k_weighted> = 20.318
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.496
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.329
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_560.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_560.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9218 - <k> = 18.436
# M[0] = 10073 - <k_weighted> = 20.146
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.504
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.337
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.6_564.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.6_564.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9130 - <k> = 18.26
# M[0] = 9953 - <k_weighted> = 19.906
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.491
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.325
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_579.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_579.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8985 - <k> = 17.97
# M[0] = 10186 - <k_weighted> = 20.372
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.596
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.425
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_583.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_583.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8919 - <k> = 17.838
# M[0] = 10149 - <k_weighted> = 20.298
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.6
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.428
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_594.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_594.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8756 - <k> = 17.512
# M[0] = 9887 - <k_weighted> = 19.774
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.593
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.422
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_596.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_596.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8906 - <k> = 17.812
# M[0] = 10048 - <k_weighted> = 20.096
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.595
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.424
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_597.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_597.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9025 - <k> = 18.05
# M[0] = 10238 - <k_weighted> = 20.476
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.601
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.43
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_602.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_602.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8694 - <k> = 17.388
# M[0] = 9921 - <k_weighted> = 19.842
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.596
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.424
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_611.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_611.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8961 - <k> = 17.922
# M[0] = 10110 - <k_weighted> = 20.22
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.605
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.434
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_614.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_614.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8618 - <k> = 17.236
# M[0] = 9714 - <k_weighted> = 19.428
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.588
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.416
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_625.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_625.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9020 - <k> = 18.04
# M[0] = 10196 - <k_weighted> = 20.392
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.606
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.435
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.75_630.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.75_630.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8739 - <k> = 17.478
# M[0] = 9943 - <k_weighted> = 19.886
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.599
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.427
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_646.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_646.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8349 - <k> = 16.698
# M[0] = 9915 - <k_weighted> = 19.83
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.706
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.546
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_650.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_650.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8544 - <k> = 17.088
# M[0] = 10119 - <k_weighted> = 20.238
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.707
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.547
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_653.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_653.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8560 - <k> = 17.12
# M[0] = 10187 - <k_weighted> = 20.374
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.708
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.548
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_668.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_668.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8558 - <k> = 17.116
# M[0] = 10145 - <k_weighted> = 20.29
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.707
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.547
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_676.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_676.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8399 - <k> = 16.798
# M[0] = 10042 - <k_weighted> = 20.084
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.702
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.541
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_680.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_680.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8577 - <k> = 17.154
# M[0] = 10259 - <k_weighted> = 20.518
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.711
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.552
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_695.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_695.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8440 - <k> = 16.88
# M[0] = 10058 - <k_weighted> = 20.116
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.7
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.538
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_706.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_706.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8392 - <k> = 16.784
# M[0] = 9984 - <k_weighted> = 19.968
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.707
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.546
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_713.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_713.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8516 - <k> = 17.032
# M[0] = 10173 - <k_weighted> = 20.346
# Sparsity [0] = 0.009
# Reciprocity (networkX) = 0.703
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.542
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.9_716.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.9_716.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8418 - <k> = 16.836
# M[0] = 9999 - <k_weighted> = 19.998
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.7
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.539
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_719.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_719.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8191 - <k> = 16.382
# M[0] = 10103 - <k_weighted> = 20.206
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.776
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.635
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_722.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_722.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8091 - <k> = 16.182
# M[0] = 10018 - <k_weighted> = 20.036
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.779
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.638
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_729.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_729.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8067 - <k> = 16.134
# M[0] = 9959 - <k_weighted> = 19.918
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.78
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.64
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_745.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_745.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8253 - <k> = 16.506
# M[0] = 10171 - <k_weighted> = 20.342
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.771
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.627
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_755.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_755.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 7859 - <k> = 15.718
# M[0] = 9740 - <k_weighted> = 19.48
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.769
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.624
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_767.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_767.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8011 - <k> = 16.022
# M[0] = 9791 - <k_weighted> = 19.582
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.772
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.629
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_773.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_773.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8058 - <k> = 16.116
# M[0] = 9927 - <k_weighted> = 19.854
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.768
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.624
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_783.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_783.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8021 - <k> = 16.042
# M[0] = 9842 - <k_weighted> = 19.684
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.77
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.627
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_786.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_786.dat
# Number of nodes = 999
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8175 - <k> = 16.366
# M[0] = 10036 - <k_weighted> = 20.092
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.777
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.635
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/theta_1000_1_2_20_0.999_800.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_conditionals_20/syn_1000_1_2_20_0.999_800.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 8310 - <k> = 16.62
# M[0] = 10309 - <k_weighted> = 20.618
# Sparsity [0] = 0.008
# Reciprocity (networkX) = 0.785
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.646

# %% [markdown]
# #### ReciprocityMMSBM_joints

# %%
avg_degree = 20
out_folder = f'../../data/input/ReciprocityMMSBM_joints_{avg_degree}/'
show_details = True
show_plots = False

np.random.seed(17)
rseed = np.random.randint(18)

# %%
for eta in [0.1, 10, 20, 40, 80, 140, 280, 500, 1500]:
    for _ in range(10):
        synthetic.ReciprocityMMSBM_joints(avg_degree=avg_degree, eta=eta, seed=rseed, out_folder=out_folder, 
                                          show_details=show_details, show_plots=show_plots)
        rseed += np.random.randint(1,18)
        print('\n')
# Out:
# ../synthetic.py:349: UserWarning: is_sparse parameter was not set. Defaulting to is_sparse=True
#   warnings.warn(msg)
# ../synthetic.py:358: UserWarning: label parameter was not set. Defaulting to label=_N_L_K_avgdegree_eta_seed
#   warnings.warn(msg)
# ../synthetic.py:377: UserWarning: perc_overlapping parameter was not set. Defaulting to perc_overlapping=0.2
#   warnings.warn(msg)
# ../synthetic.py:391: UserWarning: correlation_u_v parameter for overlapping communities was not set. Defaulting to corr=0.0
#   warnings.warn(msg)
# ../synthetic.py:399: UserWarning: alpha parameter of Dirichlet distribution was not set. Defaulting to alpha=[0.1, 0.1]
#   warnings.warn(msg)
# ../synthetic.py:422: UserWarning: structure parameter was not set. Defaulting to structure=['assortative']
#   warnings.warn(msg)
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_15.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_15.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9956 - <k> = 19.912
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.001
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_31.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_31.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9898 - <k> = 19.796
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.001
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_38.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_38.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10067 - <k> = 20.134
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.001
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_55.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_55.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9930 - <k> = 19.86
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.002
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_69.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_69.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10186 - <k> = 20.372
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.001
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_74.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_74.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10029 - <k> = 20.058
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.001
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_82.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_82.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9947 - <k> = 19.894
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.001
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_95.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_95.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10008 - <k> = 20.016
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.003
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_103.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_103.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9889 - <k> = 19.778
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.002
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_0.1_105.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_0.1_105.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9999 - <k> = 19.998
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.002
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.001
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_120.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_120.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10006 - <k> = 20.012
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.107
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.057
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_130.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_130.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10005 - <k> = 20.01
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.121
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.064
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_141.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_141.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9878 - <k> = 19.756
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.105
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.055
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_144.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_144.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9829 - <k> = 19.658
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.12
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.064
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_148.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_148.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10080 - <k> = 20.16
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.123
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.065
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_155.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_155.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10095 - <k> = 20.19
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.119
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.063
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_162.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_162.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10068 - <k> = 20.136
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.12
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.064
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_172.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_172.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9960 - <k> = 19.92
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.121
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.064
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_187.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_187.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9983 - <k> = 19.966
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.12
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.064
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_10_201.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_10_201.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9815 - <k> = 19.63
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.125
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.067
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_207.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_207.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9899 - <k> = 19.798
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.207
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.116
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_208.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_208.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9785 - <k> = 19.57
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.19
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.105
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_214.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_214.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9935 - <k> = 19.87
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.196
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.109
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_221.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_221.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9992 - <k> = 19.984
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.203
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.113
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_228.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_228.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9852 - <k> = 19.704
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.191
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.106
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_231.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_231.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10179 - <k> = 20.358
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.187
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.103
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_244.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_244.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9933 - <k> = 19.866
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.193
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.107
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_258.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_258.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10016 - <k> = 20.032
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.198
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.11
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_269.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_269.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9861 - <k> = 19.722
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.185
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.102
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_20_278.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_20_278.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10138 - <k> = 20.276
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.2
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.111
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_290.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_290.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10093 - <k> = 20.186
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.305
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.18
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_306.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_306.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10091 - <k> = 20.182
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.286
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.167
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_321.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_321.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9813 - <k> = 19.626
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.297
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.174
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_332.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_332.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10124 - <k> = 20.248
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.307
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.182
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_335.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_335.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9971 - <k> = 19.942
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.292
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.171
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_344.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_344.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9737 - <k> = 19.474
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.294
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.172
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_345.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_345.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9799 - <k> = 19.598
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.275
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.159
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_358.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_358.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10092 - <k> = 20.184
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.298
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.175
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_374.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_374.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10153 - <k> = 20.306
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.306
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.18
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_40_379.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_40_379.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9885 - <k> = 19.77
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.294
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.172
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_384.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_384.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9802 - <k> = 19.604
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.403
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.252
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_388.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_388.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9815 - <k> = 19.63
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.397
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.248
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_402.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_402.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9895 - <k> = 19.79
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.421
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.266
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_410.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_410.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10129 - <k> = 20.258
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.411
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.259
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_419.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_419.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9938 - <k> = 19.876
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.402
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.251
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_432.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_432.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9969 - <k> = 19.938
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.418
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.264
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_444.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_444.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9995 - <k> = 19.99
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.412
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.259
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_448.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_448.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9982 - <k> = 19.964
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.418
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.264
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_459.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_459.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10161 - <k> = 20.322
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.408
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.256
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_80_463.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_80_463.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9741 - <k> = 19.482
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.408
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.256
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_465.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_465.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10162 - <k> = 20.324
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.506
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.339
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_481.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_481.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10017 - <k> = 20.034
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.514
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.346
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_495.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_495.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10125 - <k> = 20.25
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.502
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.335
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_502.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_502.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10182 - <k> = 20.364
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.511
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.343
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_516.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_516.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10045 - <k> = 20.09
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.516
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.348
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_531.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_531.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9875 - <k> = 19.75
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.502
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.335
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_533.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_533.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9864 - <k> = 19.728
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.51
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.342
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_548.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_548.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10109 - <k> = 20.218
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.509
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.341
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_560.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_560.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9866 - <k> = 19.732
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.501
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.335
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_140_564.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_140_564.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10036 - <k> = 20.072
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.506
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.338
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_579.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_579.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9872 - <k> = 19.744
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.598
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.427
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_583.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_583.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10013 - <k> = 20.026
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.615
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.444
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_594.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_594.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9952 - <k> = 19.904
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.617
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.446
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_596.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_596.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9795 - <k> = 19.59
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.606
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.435
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_597.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_597.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9938 - <k> = 19.876
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.613
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.442
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_602.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_602.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10259 - <k> = 20.518
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.619
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.448
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_611.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_611.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9864 - <k> = 19.728
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.61
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.439
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_614.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_614.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9919 - <k> = 19.838
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.616
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.445
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_625.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_625.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10025 - <k> = 20.05
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.607
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.436
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_280_630.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_280_630.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9967 - <k> = 19.934
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.619
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.448
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_646.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_646.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9809 - <k> = 19.618
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.694
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.531
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_650.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_650.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9903 - <k> = 19.806
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.695
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.532
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_653.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_653.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10082 - <k> = 20.164
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.691
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.527
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_668.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_668.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10096 - <k> = 20.192
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.7
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.539
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_676.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_676.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10017 - <k> = 20.034
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.691
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.528
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_680.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_680.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10059 - <k> = 20.118
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.701
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.539
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_695.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_695.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9870 - <k> = 19.74
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.693
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.53
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_706.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_706.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10088 - <k> = 20.176
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.696
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.534
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_713.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_713.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9935 - <k> = 19.87
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.683
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.518
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_500_716.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_500_716.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9993 - <k> = 19.986
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.697
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.535
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_719.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_719.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9891 - <k> = 19.782
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.809
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.68
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_722.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_722.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9769 - <k> = 19.538
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.818
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.692
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_729.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_729.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10011 - <k> = 20.022
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.809
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.679
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_745.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_745.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10037 - <k> = 20.074
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.804
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.672
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_755.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_755.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9952 - <k> = 19.904
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.81
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.681
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_767.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_767.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10030 - <k> = 20.06
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.819
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.693
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_773.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_773.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 10219 - <k> = 20.438
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.814
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.686
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_783.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_783.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9946 - <k> = 19.892
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.806
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.675
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_786.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_786.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9958 - <k> = 19.916
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.809
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.679
#
#
# Parameters saved in: ../../data/input/ReciprocityMMSBM_joints_20/theta_1000_1_2_20_1500_800.npz
# To load: theta=np.load(filename), then e.g. theta["u"]
# Adjacency matrix saved in: ../../data/input/ReciprocityMMSBM_joints_20/syn_1000_1_2_20_1500_800.dat
# Number of nodes = 1000
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 9762 - <k> = 19.524
# Sparsity [0] = 0.01
# Reciprocity (networkX) = 0.81
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.681
