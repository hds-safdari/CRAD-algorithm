# %% [markdown]
# ### Pre-process American football datasets
# Goal : make input American football files suitable for the algorithm.
# source: http://www-personal.umich.edu/~mejn/netdata/

# %%
import pandas as pd
import networkx as nx
import numpy as np
import random

import matplotlib.pyplot as plt
# import wget

# %%
# %matplotlib notebook

# %%
def reciprocal_edges(G):
    N=G.number_of_nodes()
    nodes=list(G.nodes())
    edges=G.edges()
    unique_edges=[]
    reciprocal_list=[]
    for idxi in range(N):
        i=nodes[idxi]
        for idxj in range(idxi+1,N):
            j=nodes[idxj]
            if (i,j) in edges or (j,i) in edges: 
                unique_edges.append((i,j))
                if (i,j) in edges and (j,i) in edges: 
                    reciprocal_list.append((i,j))

    unique_edges = list(set(unique_edges))
    reciprocal = len(reciprocal_list)
 
    print("reciprocal:", reciprocal,len(unique_edges),"reciprocity:",reciprocal/float(len(unique_edges)),reciprocal/float(len(unique_edges)+reciprocal)) 
    return  unique_edges, reciprocal_list

# %%
def read_graph(df_adj, undirected=True, ego='source', alter='target', noselfloop=True,binary=False):
    """
        Create the graph by adding edges and nodes.
        It assumes that columns of layers are from l+2 (included) onwards.

        Return the list MultiDiGraph NetworkX objects.

        Parameters
        ----------
        df_adj : DataFrame
                 Pandas DataFrame object containing the edges of the graph.
        ego : str
              Name of the column to consider as source of the edge.
        alter : str
                Name of the column to consider as target of the edge.
        noselfloop : bool
                     If set to True, the algorithm removes the self-loops.

        Returns
        -------
        A : list
            List of MultiDiGraph NetworkX objects.
    """

    # build nodes
    egoID = df_adj[ego].unique()
    alterID = df_adj[alter].unique()
    nodes = list(set(egoID).union(set(alterID)))
    nodes.sort()

    L = df_adj.shape[1] - 2  # number of layers 
    # build the NetworkX graph: create a list of graphs, as many graphs as there are layers
    if undirected:
        A = [nx.MultiGraph() for _ in range(L)]
    else:
        A = [nx.MultiDiGraph() for _ in range(L)] 
    # set the same set of nodes and order over all layers
    for l in range(L):
        A[l].add_nodes_from(nodes)

    for index, row in df_adj.iterrows():
        v1 = row[ego]
        v2 = row[alter]
        for l in range(L):
            if row[l + 2] > 0:
                if A[l].has_edge(v1, v2):
                    if binary == True:
                        A[l][v1][v2][0]['weight'] = max(int(row[l + 2]),1)
                    else:
                        A[l][v1][v2][0]['weight'] += int(row[l + 2])  # the edge already exists -> no parallel edge created 
                else:
                    if binary == True:
                        A[l].add_edge(v1, v2, weight=max(int(row[l + 2]),1))
                    else:
                        A[l].add_edge(v1, v2, weight=int(row[l + 2]))

    # remove self-loops
    if noselfloop:
        for l in range(L):
            A[l].remove_edges_from(list(nx.selfloop_edges(A[l])))

    return A[0]

# %%
# !pwd
# Out:
# /Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/data/input

# %%
# !ls

# %%
outnet = 'football'
H = nx.read_gml("football/football.gml")
edge_list = H.edges 
node_list = H.nodes

# %%
list(H.nodes(data=True))[0:5]
# Out:
# [('BrighamYoung', {'value': 7}),
#  ('FloridaState', {'value': 0}),
#  ('Iowa', {'value': 2}),
#  ('KansasState', {'value': 3}),
#  ('NewMexico', {'value': 7})]

# %%
list(H.edges())[0:5]
# Out:
# [('BrighamYoung', 'FloridaState'),
#  ('BrighamYoung', 'NewMexico'),
#  ('BrighamYoung', 'SanDiegoState'),
#  ('BrighamYoung', 'Wyoming'),
#  ('BrighamYoung', 'Utah')]

# %% [markdown]
# ### Build graph

# %%
G = nx.Graph() 
G.add_nodes_from(H.nodes(data=True))
# G.add_weighted_edges_from(H.edges)

# %%
# edges = []
# for i in H.edges:  
#     if i[2] == 1:
#         G.add_weighted_edges_from([(i[0], i[1], 2.)])
#         edges.append((i[0], i[1]))
#     elif i[2] == 0 and (i[0], i[1]) not in edges:
#         G.add_weighted_edges_from([(i[0], i[1], 1.)])
edges = []
for i in H.edges:     
    G.add_weighted_edges_from([(i[0], i[1], 1)])
    G.add_weighted_edges_from([(i[1], i[0], 1)])

# %%
list(G.edges())[0:5]
# Out:
# [('BrighamYoung', 'FloridaState'),
#  ('BrighamYoung', 'NewMexico'),
#  ('BrighamYoung', 'SanDiegoState'),
#  ('BrighamYoung', 'Wyoming'),
#  ('BrighamYoung', 'Utah')]

# %%
# list(G.nodes(data=True))[:5]
list(G.nodes.data('value'))[:5]
# Out:
# [('BrighamYoung', 7),
#  ('FloridaState', 0),
#  ('Iowa', 2),
#  ('KansasState', 3),
#  ('NewMexico', 7)]

# %%
G.number_of_nodes(),G.number_of_edges()
# Out:
# (115, 613)

# %%
G1 = nx.convert_node_labels_to_integers(G, first_label=0)

# %% [markdown]
# ### Remove self loops

# %%
G1.number_of_nodes(),G1.number_of_edges()
# Out:
# (115, 613)

# %%
node_att = list(G1.nodes('value'))

# %%
nd_col = []
for idx,nd_vi in enumerate(G1.nodes):
    nd_col.append(G1.nodes[nd_vi]["value"])
print(idx, len(nd_col))
# Out:
# 114 115

# %%
N = len(list(G1.nodes()))
K = 12

gt_com = list(G1.nodes('value')) 

theta_gt = np.zeros((N,K))
theta_gt.shape
for idx, nod in enumerate(gt_com):
    theta_gt[idx,nod[1]] = 1

# %%
np.savez('theta_gt_football', u=theta_gt, v=theta_gt)

# %%
theta_gt1 = np.load('theta_gt_football.npz',allow_pickle=True)

# %%
G1nodes = list(G1.nodes())
pos = nx.spring_layout(G1)

# %%
# subG = np.random.choice(G1nodes,400)
# k = G1.subgraph(subG)  
umax=np.argmax(theta_gt,1)
k =G1

plt.figure(figsize=(10,6))
nx.draw_networkx(k, pos=pos,with_labels=True,node_color = umax,node_size=400)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def output_adjacency(G, outfile = None):
    """
        Output the adjacency matrix. Default format is space-separated .csv
        with 3 columns: node1 node2 weight
        INPUT
        ----------
        G: Digraph
           DiGraph NetworkX object.
        outfile: str
                 Name of the adjacency matrix.
    """
#     folder = '../data/input/RD/' 
    outfile = outfile 
    edges = list(G.edges(data=True)) 
    try:
        data = [[u, v, d['weight']] for u, v, d in edges]
    except:
        data = [[u, v, 1] for u, v, d in edges] 
    df = pd.DataFrame(data, columns=['source', 'target', 'w'], index=None)
    df.to_csv('RD/'+outfile, index=False, sep=' ')

# %% [markdown]
# ### Output on file

# %%
outfile = outnet+'.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
# nx.write_weighted_edgelist(G1, outfile)
output_adjacency(G1, outfile= outfile)
print(outfile)
# Out:
# football.dat

# %% [markdown]
# # Read dataset from txt file

# %%
outnet='football'
net = ''
input_data = pd.read_csv(outnet+net+'.dat', header=None, skiprows=1, sep='\s+', comment='#')

# %%
df = pd.DataFrame(input_data)
df.head(n=5)
# Out:
#    0  1
# 0  1  2
# 1  1  3
# 2  1  4
# 3  1  5
# 4  1  6

# %%
df[2] = 1
df.head(n=5)
# Out:
#    0  1  2
# 0  1  2  1
# 1  1  3  1
# 2  1  4  1
# 3  1  5  1
# 4  1  6  1

# %%
dict = {0: 'source',
        1: 'target',
        2: 'w'}
   
df.rename(columns=dict,
          inplace=True)

# %%
G1 = read_graph(df,undirected=True)

# %%
G1nodes = list(G1.nodes())
pos = nx.spring_layout(G1)
# subG = np.random.choice(G1nodes,400)
# k = G1.subgraph(subG)  
k =G1
plt.show()
fig = plt.figure(figsize=(10,4))
nx.draw_networkx(k, pos=pos,node_color = 'orange',with_labels=True,node_size=200)
fig.savefig(net+'.png', dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
net = 'football_1'
outfile = net+'.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
# nx.write_weighted_edgelist(G1, outfile)
output_adjacency(G1, outfile= outfile)
print(outfile)
# Out:
# football_1.dat

# %% [markdown]
# # Injecting Anomaly

# %%
import random

# %%
G2=nx.Graph(G1)

# %%
theta_gt_z = np.zeros((N, N), dtype=float)

nd_list = list(G1.nodes()) 
thrsh = 0.05*(G1.number_of_edges())
anomalous_edges = []
while len(anomalous_edges) <= thrsh: 
    nd1, nd2 = random.sample(nd_list, 2) 
    if (nd1, nd2) not in G1.edges():
        if (nd1, nd2) not in G2.edges(): 
            anomalous_edges.append((nd1, nd2)) 
            anomalous_edges.append((nd2, nd1)) 
            theta_gt_z[nd1, nd2] = 1
            theta_gt_z[nd2, nd1] = 1
             
            G2.add_edges_from([(nd1, nd2)], weight=1) 
#             print(nd1, nd2, len(anomalous_edges), anomalous_edges)
print(G1.number_of_edges(),G2.number_of_edges(),len(anomalous_edges),anomalous_edges)
# Out:
# 613 629 32 [(58, 25), (25, 58), (88, 23), (23, 88), (54, 78), (78, 54), (105, 32), (32, 105), (103, 38), (38, 103), (50, 58), (58, 50), (79, 58), (58, 79), (20, 48), (48, 20), (70, 102), (102, 70), (13, 37), (37, 13), (35, 65), (65, 35), (79, 86), (86, 79), (8, 104), (104, 8), (94, 15), (15, 94), (88, 13), (13, 88), (94, 90), (90, 94)]

# %%
np.savez('theta_gt_z_footbal', z=theta_gt_z)
theta_gtz = np.load('theta_gt_z_footbal.npz',allow_pickle=True)

# %%
# nd_list = list(G2.nodes()) 
# nd_in = random.sample(nd_list, int(len(nd_list)*0.03)) 
# set_difference = set(nd_list) - set(nd_in)
# list_difference = list(set_difference) 
# nd_out = random.sample(list_difference, int(len(nd_list)*0.03))
# print(nd_in,nd_out)

# %%
# anomalous_edges = []
# num_edge = 1
# for rn_node in nd_in: 
#     set_difference = set(nd_out)  - set(list(G2.neighbors(rn_node)))
#     list_difference = list(set_difference)  
# #     print(nd_out, list(G2.neighbors(rn_node)))
    
#     l = [rn_node] * len(list_difference)
#     rn_edge  = list(zip(l,list_difference))
#     rn_edger = list(zip(list_difference,l))
    
#     G2.add_edges_from(rn_edge, weight=1) 
#     G2.add_edges_from(rn_edger, weight=1) 
    
#     anomalous_edges.extend(rn_edge)
# #     anomalous_edges.extend(rn_edger)

# %%
# anomalous_edges = [(22,95),(51,37),(7,42),(84,13),(52,109),(97,34),(84,7),
#                    (58,42),(29,1),(2,76),(2,62),(0,18),(4,33),
#                    (31,8),(103,24),(111,76),(107,54),(39,56),(0,77),(50,105)]
# G2.add_edges_from(anomalous_edges)

# %%
len(anomalous_edges), G1.number_of_edges()
# Out:
# (32, 613)

# %%
len(anomalous_edges), G2.number_of_edges()
# Out:
# (32, 629)

# %%
np.savetxt('RD/'+outnet+'_anomalous_edges.dat', anomalous_edges, delimiter=" ")

# %%
restart = False
if restart:
    df_anomalous_edges = pd.read_csv('RD/'+outnet+'_anomalous_edges.dat', sep='\s+', header=None) 

    a_edgelist = df_anomalous_edges.values.astype(int)
    # G3 = nx.Graph()

    # G3.add_nodes_from(np.unique(a_edgelist))
    G2.add_edges_from(list(zip(a_edgelist[:,0], a_edgelist[:,1])))
    print('len(G2.edges())-len(G1.edges()):', len(G2.edges())-len(G1.edges()))
    print('G2.number_of_nodes(),G2.number_of_edges()', G2.number_of_nodes(),G2.number_of_edges())
    anomalous_edges = list(zip(a_edgelist[:,0], a_edgelist[:,1]))

# %%
outfile = outnet + '_injected.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
# nx.write_weighted_edgelist(G1, outfile)
output_adjacency(G2, outfile = outfile)
print(outfile)
# Out:
# football_injected.dat

# %% [markdown]
# # Inference Task

# %%
import sys  
# sys.path.insert(0, '../../code/')
# import file

# %%
import numpy as np
import pandas as pd

import tools as tl
# import AnomalyDetection as adet
import cv_functions as cvfun

import matplotlib.pyplot as plt
import networkx as nx
import importlib
import sktensor as skt
from sklearn import metrics
from sklearn.metrics import f1_score

import importlib
# import time_glob as gl
# %matplotlib inline

# %%
cmap = 'PuBuGn'

def expected_Aija(U,V,W):
    if W.ndim==1:
        M=np.einsum('ik,jk->ijk',U,V)
        M=np.einsum('ijk,k->ij',M,W)
    else:    
        M=np.einsum('ik,jq->ijkq',U,V)
        M=np.einsum('ijkq,kq->ij',M,W)
    return M

# %%
# gl.timer.verbose = True
# gl.timer.color = 'green'
# gl.timer.print_details = False
# gl.timer.print_sub = True
# gl.printer.verboseness = True
# gl.parallelize = False

# label = net+'.dat' 
# flag_anomaly = 'False'


flag_anomaly = 'True'
label = outnet+'_injected.dat' 

dir0 = '../output/5-fold_cv/'
dir1 = dir0 + 'RDall/edge_anomalies/'

K = 12

# # original parameters
theta = np.load(dir1+'theta_inf_'+flag_anomaly+'_'+label+'_0K'+str(K)+'.npz',allow_pickle=True)
# # define some support files
# np.savetxt("../data/input/u.dat", theta['u'], delimiter=" ")
# np.savetxt("../data/input/v.dat", theta['v'], delimiter=" ")
# np.savetxt("../data/input/z.dat", theta['z'], delimiter=" ") 
theta['mupr'],theta['pibr'],theta['u'].shape 


importlib.reload(tl) 
network = 'RD/'+label
network1 = 'RD/football.dat'
print('network:', network)
A, B, B_T, data_T_vals = tl.import_data(network,header=0)
A1, B1, B_T1, data_T_vals1 = tl.import_data(network1,header=0)
nodes = A[0].nodes()
pos = nx.spring_layout(A[0]) 
N = len(nodes)
L = B.shape[0]
K = theta['u'].shape[-1]
print(N, A[0].number_of_edges())


# node_col =[]
# for idx,node in enumerate(G2.nodes()):
# #     print(idx,node)

#     # if the node has the attribute group1
# #     print(np.argmax(theta['u'][idx], axis=-1))
#     if np.argmax(theta['u'][idx], axis=-1) == 0:
#         node_col.append('red')

#     # if the node has the attribute group1
#     if np.argmax(theta['u'][idx], axis=-1) == 1:
#         node_col.append('green') 
        

importlib.reload(cvfun)
flag_anomaly = True
M0 = cvfun._lambda0_full(theta['u'], theta['v'], theta['w'])
if flag_anomaly == False:
    Q = np.zeros_like(M0)
else:
    Q = cvfun.calculate_Q_dense(B,M0,theta['pibr'], theta['mupr'])
M = cvfun.calculate_expectation(theta['u'],theta['v'],theta['w'],Q[0],theta['pibr'])

Q = cvfun.calculate_Q_dense(B,M0,theta['pibr'], theta['mupr'])


plt.figure(figsize=(4,4))
plt.hist(Q.flatten())
plt.show()


plt.figure(figsize=(4,4)) 
plt.imshow(Q[0], cmap=cmap, interpolation='nearest')
# plt.colorbar(fraction=0.046)
cax = plt.axes([0.85, 0.1, 0.075, 0.8])
plt.colorbar(cax=cax)
plt.title('Q')
plt.show()

print(np.max(Q[0]), np.min(Q[0]))
# Out:
# network: RD/football_injected.dat
# RD/football_injected.dat shape: (629, 3)
# Number of nodes = 115
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 629 - <k> = 10.939
# M[0] = 629 - <k_weighted> = 10.939
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
# Reciprocity (considering the weights of the edges) = 1.0
# RD/football.dat shape: (613, 3)
# Number of nodes = 115
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 613 - <k> = 10.661
# M[0] = 613 - <k_weighted> = 10.661
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
# Reciprocity (considering the weights of the edges) = 1.0
# 115 629
# 1.0 1.1111111111209876e-25

# %%
threshold = 0.99
Z_pred = np.copy(Q[0])
Z_pred[Z_pred<threshold] = 0
Z_pred[Z_pred>=threshold] = 1

# %%
plt.figure(figsize=(16,10))
plt.subplot(1, 3, 1)
plt.imshow(theta_gtz['z'], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('Z')
plt.subplot(1, 3, 2)
plt.imshow(Z_pred, cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('Z_pred')
plt.subplot(1, 3, 3)
plt.imshow(Q[0], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('Q')
plt.show()

# %%
# threshold = 0.1 # 1.*np.max(Q[0])/2.
# count = []
# inferred_nodes = []
# inferred_edges = []
# idn = 0
# for idx,ndi in enumerate(A[0].nodes()):
#     for jdx,ndj in enumerate(A[0].nodes()):
#         if Q[0,idx,jdx] > threshold:
#             if (ndi,ndj) in A[0].edges(): 
#                 if (ndj,ndi) not in inferred_edges:
#                     inferred_edges.append((ndi,ndj))
#                     inferred_nodes.append(ndi)
#                     inferred_nodes.append(ndj) 
#                     count.append(Q[0,idx,jdx]) 
# #                 print(Q[0,idx,jdx], ndi,ndj)
#                 idn = idn+1
# #             elif (ndj,ndi) in A[0].edges():
# #                 inferred_nodes.append(ndi)
# #                 inferred_nodes.append(ndj)
# #                 inferred_edges.append((ndj,ndi))
# #                 count.append(Q[0,jdx,idx])
# #                 idn = idn+1
# # print((len(count)/(N*N))*100)

# %%
threshold = 1.0 # 1.*np.max(Q[0])/2.
count = []
inferred_nodes = []
inferred_edges = []
idn = 0
ind_num = 0
ind_num2 = 0
for idx,ndi in enumerate(A[0].nodes()):
    for jdx,ndj in enumerate(A[0].nodes()):
        if Q[0,idx,jdx] >= threshold:
            if (B[0,ndi,ndj] >= 1) and (B[0,ndj,ndi] >= 1):  
                if (ndi,ndj) in anomalous_edges:
                    ind_num = ind_num+1
#                     print((ndi,ndj))
                    inferred_edges.append((ndi,ndj))
                    inferred_nodes.append(ndi)
                    inferred_nodes.append(ndj) 
            elif (B[0,ndi,ndj] == 0) or (B[0,ndj,ndi] == 0): 
                ind_num2 = ind_num2+1
                if (ndj,ndi) not in inferred_edges:
                    inferred_edges.append((ndi,ndj))
                    inferred_nodes.append(ndi)
                    inferred_nodes.append(ndj) 
                    count.append(Q[0,idx,jdx]) 
#                 print(Q[0,idx,jdx], ndi,ndj)
                idn = idn+1
#             elif (ndj,ndi) in A[0].edges():
#                 inferred_nodes.append(ndi)
#                 inferred_nodes.append(ndj)
#                 inferred_edges.append((ndj,ndi))
#                 count.append(Q[0,jdx,idx])
#                 idn = idn+1
# print((len(count)/(N*N))*100)
print(ind_num,ind_num2)
# Out:
# 0 0

# %%
inferred = inferred_edges

injected = anomalous_edges 
# set(injected) - set(inferred)
print('len(injected).intersection(inferred)):', len(set(injected).intersection(set(inferred))))
print('# of inferred anomalous edges:', len(set(inferred)))
print('# of injected anomalous edges:', len(set(injected)))
# print(set(injected).intersection(set(inferred)))
# (len(set(injected).intersection(set(inferred))))/len(set(injected))*100
# Out:
# len(injected).intersection(inferred)): 30
# # of inferred anomalous edges: 30
# # of injected anomalous edges: 31

# %%
G3 = nx.Graph()
G3.add_nodes_from(G1.nodes()) 
G3.add_edges_from(inferred_edges)

# %%
# umax = np.zeros(len(G3.nodes())) 
# for idx, ui in enumerate(G3.nodes()): 
# #     print(theta['u'][idx])
# #     print(np.argmax(theta['u'][idx]))
#     umax[idx] = np.argmax(theta['u'][idx])

# %%
umax=np.argmax(theta['u'],1)#max of each u

# plt.figure(figsize=(14,10))
nodelist = G1.nodes()
N = len(list(G1.nodes()))
K = 2
# for k in range(K+1):
# for k in [0, 1]:
#     nodelist.extend([i for i in range(N) if umax[i]==k])

pos = nx.spring_layout(G2, seed=2) 
fig, axes = plt.subplots(nrows=3, ncols=1,figsize=(12,22))
ax = axes.flatten()

# fig = plt.figure(figsize=(12,6))
kk = G3
nx.draw(kk,pos=pos, with_labels=True,node_color = umax,cmap = plt.cm.Set1, node_size=400,ax=ax[0]) 
nx.draw_networkx_edges(G3, pos, edgelist=inferred_edges, arrows=False, width = 2,alpha=0.25,ax=ax[0]) 
# nx.draw_networkx_edges(G3, pos, edgelist=red_edges, edge_color='r', arrows=False, width=2,alpha=0.95) 
ax[0].set_axis_off()

umax=np.argmax(theta['u'],1)
pos = nx.spring_layout(G2, seed=2)
# nx.draw_networkx(G2, pos=pos,cmap = plt.cm.Set1,node_color=umax,with_labels=True,node_size=400,ax=ax[1]) 
nx.draw(G2,pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,node_size=400,ax=ax[1]) 


umax=np.argmax(theta_gt1['u'],1)
pos = nx.spring_layout(G2, seed=2)
# nx.draw_networkx(G2, pos=pos,cmap = plt.cm.Set1,node_color=umax,with_labels=True,node_size=400,ax=ax[1]) 
nx.draw(G1,pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,node_size=400,ax=ax[2])

plt.show()
# fig.tight_layout()
fig.savefig(outnet+'_graph_anomaly.png', dpi=200)

# %%
# umax=np.argmax(theta['u'],1)#max of each u

# plt.figure(figsize=(14,10))
nodelist = nodes
N = len(list(nodes))
K = 12
# for k in range(K+1):
# for k in [0, 1]:
#     nodelist.extend([i for i in range(N) if umax[i]==k])

pos = nx.spring_layout(G3,seed=10)      
fig = plt.figure(figsize=(18,6))
kk = G3
nx.draw(kk,pos=pos, with_labels=True,node_color = umax,cmap = plt.cm.Set1, node_size=650) 
nx.draw_networkx_edges(G3, pos, edgelist=edges, arrows=False, width = 2,alpha=0.25) 
# nx.draw_networkx_edges(G3, pos, edgelist=red_edges, edge_color='r', arrows=False, width=2,alpha=0.95) 
# ax[0].set_axis_off()

plt.show()
# fig.tight_layout()
fig.savefig(outnet+'_graph_anomaly.png', dpi=200)

# %%
import tools as tl
import cv_functions as cvfun
import importlib

# %%
importlib.reload(tl) 
importlib.reload(cvfun)
# Out:
# <module 'cv_functions' from '/Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/data/input/cv_functions.py'>

# %%
# dir1 = '../data/output/5-fold_cv/RDall/edge_anomalies/' 
dir1 = 'RD/' 
network = dir1+outnet+'_injected.dat'

A, B, B_T, data_T_vals = tl.import_data(network,header=0)
nodes = A[0].nodes()
pos = nx.spring_layout(A[0]) 
N = len(nodes)
L = B.shape[0] 
print(N)
# Out:
# RD/football.dat shape: (613, 3)
# Number of nodes = 115
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 613 - <k> = 10.661
# M[0] = 613 - <k_weighted> = 10.661
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
# Reciprocity (considering the weights of the edges) = 1.0
# 115

# %% [markdown]
# # Anomaly

# %%
dir1 = '../output/5-fold_cv/RDall/edge_anomalies/'
# dir1 = dir0 + 'RDall/edge_anomalies/'
dir_o = 'RD/'
outnet_i = 'football_injected' 
flag_anomaly = True
K = 12

theta_an = np.load(dir1+'theta_inf_'+str(flag_anomaly)+'_'+outnet_i+'.dat_0K'+str(K)+'.npz',allow_pickle=True)
# theta_an = np.load(dir1+'theta_inf_False_Physicians_1.dat_0K'+str(K)+'.npz',allow_pickle=True)
theta_an['u'].shape
# Out:
# (115, 12)

# %% [markdown]
# # Anomaly0

# %%
dir1 = '../output/5-fold_cv/RDall/edge_anomalies/'
# dir1 = dir0 + 'RDall/edge_anomalies/'
dir_o = 'RD/'
outnet_i = 'football'
flag_anomaly = False 
K = 12
theta_an0 = np.load(dir1+'theta_inf_'+str(flag_anomaly)+'_'+outnet_i+'.dat_0K'+str(K)+'.npz',allow_pickle=True)
theta_an0['u'].shape
# Out:
# (115, 12)

# %% [markdown]
# # BPTF

# %%
dir1 = '../output/5-fold_cv/RDall/bptf/'
# dir1 = dir0 + 'RDall/edge_anomalies/'
dir_o = '../data/input/RD/'
outnet_i = 'football'  

theta_bptf = np.load(dir1+'theta_K'+str(K)+'_'+outnet_i+'.npz',allow_pickle=True)
theta_bptf['u'].shape
# Out:
# (115, 12)

# %% [markdown]
# # MT

# %%
dir1 = '../output/5-fold_cv/RDall/mt/'
# dir1 = dir0 + 'RDall/edge_anomalies/'
dir_o = '../data/input/RD/'
outnet_i = 'football'  

theta_mt = np.load(dir1+'theta_K'+str(K)+'_'+outnet_i+'.npz',allow_pickle=True)  
theta_mt['u'].shape
# Out:
# (115, 12)

# %% [markdown]
# # CRep

# %%
dir1 = '../output/5-fold_cv/RDall/edge_anomalies/'
# dir1 = dir0 + 'RDall/edge_anomalies/'
dir_o = 'RD/'
outnet_i = 'football'  

theta_crep = np.load('../output/5-fold_cv/RD/edge_anomalies/theta_'+outnet_i+'_K'+str(K)+'_CRep0.npz',allow_pickle=True)

# %%
pos = nx.spring_layout(A[0],seed=42) 
umax=np.argmax(theta_an['u'],1)#max of each u

nodelist = []
for k in range(K+1):
    nodelist.extend([i for i in range(N) if umax[i]==k])
    
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(10,10))
ax = axes.flatten()

nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[0])
ax[0].set_axis_off()

umax=np.argmax(theta_an0['u'],1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[1])


umax=np.argmax(theta_crep['u'],1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[2])


umax=np.argmax(theta_mt['u'],1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[3])

umax=np.argmax(theta_bptf['u'],1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[4])


umax=np.argmax(theta_gt,1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[5])
plt.show()

# %%
umax=np.argmax(theta_gt,1)#max of each u
# plt.figure(figsize=(14,10))
nodelist = []
for k in range(K+1):
    nodelist.extend([i for i in range(N) if umax[i]==k])
    
fig, axes = plt.subplots(nrows=1, ncols=3,figsize=(10,6))
ax = axes.flatten()

nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[0])
ax[0].set_axis_off()

umax=np.argmax(theta_an0['u'],1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = nd_col,cmap = plt.cm.Set1,ax=ax[1])


umax=np.argmax(theta_crep['u'],1)#max of each u
nx.draw(A[0],pos=pos, arrows=False, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[2])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
u, cs_u = cvfun.cosine_similarity(theta_crep['u'], theta_bptf['u']) 
v, cs_v = cvfun.cosine_similarity(theta_crep['v'], theta_bptf['v']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_bptf['u'])
v1 = cvfun.normalize_nonzero_membership(theta_bptf['v'])
u2 = cvfun.normalize_nonzero_membership(theta_crep['u'])
v2 = cvfun.normalize_nonzero_membership(theta_crep['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.377607760177235 0.44553187122797255
# 0.3614 0.3957

# %%
u, cs_u = cvfun.cosine_similarity(theta_mt['u'], theta_crep['u']) 
v, cs_v = cvfun.cosine_similarity(theta_mt['v'], theta_crep['v']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_mt['u'])
v1 = cvfun.normalize_nonzero_membership(theta_mt['v'])
u2 = cvfun.normalize_nonzero_membership(theta_crep['u'])
v2 = cvfun.normalize_nonzero_membership(theta_crep['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.9993414623683091 0.9993414623683098
# 0.9878 0.9878

# %%
u, cs_u = cvfun.cosine_similarity(theta_crep['u'], theta_an0['u']) 
v, cs_v = cvfun.cosine_similarity(theta_crep['v'], theta_an0['v']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_mt['u'])
v1 = cvfun.normalize_nonzero_membership(theta_mt['v'])
u2 = cvfun.normalize_nonzero_membership(theta_an0['u'])
v2 = cvfun.normalize_nonzero_membership(theta_an0['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.8529637983158056 0.8572575318981399
# 0.7582 0.7582

# %%
u, cs_u = cvfun.cosine_similarity(theta_mt['u'], theta_an0['u']) 
v, cs_v = cvfun.cosine_similarity(theta_mt['v'], theta_an0['v']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_mt['u'])
v1 = cvfun.normalize_nonzero_membership(theta_mt['v'])
u2 = cvfun.normalize_nonzero_membership(theta_an0['u'])
v2 = cvfun.normalize_nonzero_membership(theta_an0['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.8527156280961808 0.8570093616785055
# 0.7582 0.7582

# %%
u, cs_u = cvfun.cosine_similarity(theta_an0['u'], theta_an['u']) 
v, cs_v = cvfun.cosine_similarity(theta_an0['v'], theta_an['v']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(u)
v1 = cvfun.normalize_nonzero_membership(v)

f1_u = cvfun.evalu(theta_an0['u'], theta_an['u'], 'f1')
f1_v = cvfun.evalu(theta_an0['v'], theta_an['v'], 'f1')
print(f1_u, f1_v)
# Out:
# 0.8031007475945833 0.8031007475945833
# 0.0 0.0

# %%
u, cs_u = cvfun.cosine_similarity(theta_bptf['u'], theta_gt1['u']) 
v, cs_v = cvfun.cosine_similarity(theta_bptf['v'], theta_gt1['u']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_bptf['u'])
v1 = cvfun.normalize_nonzero_membership(theta_bptf['v'])
u2 = cvfun.normalize_nonzero_membership(theta_gt1['u'])
v2 = cvfun.normalize_nonzero_membership(theta_gt1['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.3502738765979469 0.34627359609440433
# 0.3016 0.3447

# %%
u, cs_u = cvfun.cosine_similarity(theta_mt['u'], theta_gt1['u']) 
v, cs_v = cvfun.cosine_similarity(theta_mt['v'], theta_gt1['u']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_mt['u'])
v1 = cvfun.normalize_nonzero_membership(theta_mt['v'])
u2 = cvfun.normalize_nonzero_membership(theta_gt1['u'])
v2 = cvfun.normalize_nonzero_membership(theta_gt1['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.9029642576975645 0.9029642576975062
# 0.5718 0.5718

# %%
u, cs_u = cvfun.cosine_similarity(theta_crep['u'], theta_gt1['u']) 
v, cs_v = cvfun.cosine_similarity(theta_crep['v'], theta_gt1['u']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_crep['u'])
v1 = cvfun.normalize_nonzero_membership(theta_crep['v'])
u2 = cvfun.normalize_nonzero_membership(theta_gt1['u'])
v2 = cvfun.normalize_nonzero_membership(theta_gt1['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.9031094525049695 0.9031094525049124
# 0.5707 0.5707

# %%
u, cs_u = cvfun.cosine_similarity(theta_an0['u'], theta_gt1['u']) 
v, cs_v = cvfun.cosine_similarity(theta_an0['v'], theta_gt1['u']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_an0['u'])
v1 = cvfun.normalize_nonzero_membership(theta_an0['v'])
u2 = cvfun.normalize_nonzero_membership(theta_gt1['u'])
v2 = cvfun.normalize_nonzero_membership(theta_gt1['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.9077959027707097 0.9077959027707097
# 0.5848 0.5848

# %%
u, cs_u = cvfun.cosine_similarity(theta_an['u'], theta_gt1['u']) 
v, cs_v = cvfun.cosine_similarity(theta_an['v'], theta_gt1['u']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_an['u'])
v1 = cvfun.normalize_nonzero_membership(theta_an['v'])
u2 = cvfun.normalize_nonzero_membership(theta_gt1['u'])
v2 = cvfun.normalize_nonzero_membership(theta_gt1['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# 0.808695652173913 0.808695652173913
# 0.7373 0.7373

# %%
u, cs_u = cvfun.cosine_similarity(theta_an['u'], theta['u']) 
v, cs_v = cvfun.cosine_similarity(theta_an['v'], theta['v']) 
print(cs_u, cs_v)

u1 = cvfun.normalize_nonzero_membership(theta_an['u'])
v1 = cvfun.normalize_nonzero_membership(theta_an['v'])
u2 = cvfun.normalize_nonzero_membership(theta['u'])
v2 = cvfun.normalize_nonzero_membership(theta['v'])

f1_u = cvfun.evalu(u1, u2, 'f1')
f1_v = cvfun.evalu(v1, v2, 'f1')
print(f1_u, f1_v)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-151-e7a1cbfe02e0> in <module>
# ----> 1 u, cs_u = cvfun.cosine_similarity(theta_an['u'], theta['u'])
#       2 v, cs_v = cvfun.cosine_similarity(theta_an['v'], theta['v'])
#       3 print(cs_u, cs_v)
#       4
#       5 u1 = cvfun.normalize_nonzero_membership(theta_an['u'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     252             if magic == format.MAGIC_PREFIX:
#     253                 bytes = self.zip.open(key)
# --> 254                 return format.read_array(bytes,
#     255                                          allow_pickle=self.allow_pickle,
#     256                                          pickle_kwargs=self.pickle_kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     777                     read_count = min(max_read_count, count - i)
#     778                     read_size = int(read_count * dtype.itemsize)
# --> 779                     data = _read_bytes(fp, read_size, "array data")
#     780                     array[i:i+read_count] = numpy.frombuffer(data, dtype=dtype,
#     781                                                              count=read_count)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/format.py in _read_bytes(fp, size, error_template)
#     906         # done about that.  note that regular files can't be non-blocking
#     907         try:
# --> 908             r = fp.read(size - len(data))
#     909             data += r
#     910             if len(r) == 0 or len(data) == size:
#
# ~/opt/anaconda3/lib/python3.8/zipfile.py in read(self, n)
#     938         self._offset = 0
#     939         while n > 0 and not self._eof:
# --> 940             data = self._read1(n)
#     941             if n < len(data):
#     942                 self._readbuffer = data
#
# ~/opt/anaconda3/lib/python3.8/zipfile.py in _read1(self, n)
#    1028         if self._left <= 0:
#    1029             self._eof = True
# -> 1030         self._update_crc(data)
#    1031         return data
#    1032
#
# ~/opt/anaconda3/lib/python3.8/zipfile.py in _update_crc(self, newdata)
#     956         # Check the CRC if we're at the end of the file
#     957         if self._eof and self._running_crc != self._expected_crc:
# --> 958             raise BadZipFile("Bad CRC-32 for file %r" % self.name)
#     959
#     960     def read1(self, n):
#
# BadZipFile: Bad CRC-32 for file 'u.npy'
