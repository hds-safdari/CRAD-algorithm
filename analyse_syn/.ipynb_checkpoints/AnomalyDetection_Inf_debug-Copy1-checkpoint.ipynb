# %%
import numpy as np
import pandas as pd

import tools as tl
import AJointCRep_AnomalyDetection as adet 
import cv_functions as cvfun

import matplotlib.pyplot as plt
import networkx as nx
import importlib
import sktensor as skt
from sklearn import metrics
from sklearn.metrics import f1_score

import time_glob as gl
# %matplotlib inline

# %%
cmap = 'PuBuGn'

def expected_Aija(U,V,W):
    if W.ndim==1:
        M=np.einsum('ik,jk->ijk',U,V)
        M=np.einsum('ijk,k->ij',M,W)
    else:    
        M=np.einsum('ik,jq->ijkq',U,V)
        M=np.einsum('ijkq,kq->ij',M,W)
    return M

# %%
gl.timer.verbose = True
gl.timer.color = 'green'
gl.timer.print_details = False
gl.timer.print_sub = True
gl.printer.verboseness = True
gl.parallelize = False

# %%
# %matplotlib notebook

# %%
label = '500_3_60_99_0.4_1_7'
label = 'syn_'+label
# label = 'dutch2_6'

# %%
dir0 = '../data/input/'
dir1 = dir0 + 'synthetic/edge_anomalies/'
# dir1 = dir0

# %%
# # original parameters
theta = np.load(dir1+'theta_'+label.split('syn_')[-1]+'.npz',allow_pickle=True)
# # define some support files
np.savetxt("../data/input/u.dat", theta['u'], delimiter=" ")
np.savetxt("../data/input/v.dat", theta['v'], delimiter=" ")
# np.savetxt("../data/input/z.dat", theta['z'], delimiter=" ")

theta['u'].shape
# Out:
# (500, 3)

# %%
theta['mu'], theta['pi'], theta['eta']
# Out:
# (array(0.20831663), array(0.4), array(1))

# %%
dir1+'theta_'+label.split('syn_')[-1]+'.npz'
# Out:
# '../data/input/synthetic/edge_anomalies/theta_500_3_60_99_0.4_1_7.npz'

# %%
importlib.reload(tl)
# Out:
# <module 'tools' from '/Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/Reciprocity_Anomaly/code_new/tools.py'>

# %%
network = dir1 +label+'.dat' 
A, B, B_T, data_T_vals = tl.import_data(network,header=0, force_dense =True)
nodes = A[0].nodes()
pos = nx.spring_layout(A[0],seed = 42) 
N = len(nodes)
L = B.shape[0]
K = theta['u'].shape[-1]
print(N, K, L)
# Out:
# ../data/input/synthetic/edge_anomalies/syn_500_3_60_99_0.4_1_7.dat shape: (14954, 3)
# Number of nodes = 500
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 14954 - <k> = 59.816
# M[0] = 14954 - <k_weighted> = 59.816
# Reciprocity (networkX) = 0.281
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.164
# Reciprocity (considering the weights of the edges) = 0.281
# 500 3 1

# %% [markdown]
# ### Initializing near ground truth

# %%
# len(data_AtAtm1.vals),len(subs_nzp[0]),len(data_T_vals),len(data.nonzero()[0])

# %%
# fold = 1
# prng = np.random.RandomState(seed=10)
# rseed = prng.randint(1000)
# indices = cvfun.shuffle_indices_all_matrix(N, L, rseed=rseed)
# mask = cvfun.extract_mask_kfold(indices, N, fold=fold, NFold=5)

# %%
mask = None

# %%
# mask_nz = np.load('../data/output/5-fold_cv/mask_f1_100_3_20.0_0.2_False_10.pkl',allow_pickle=True)
# mask = np.zeros_like(B).astype('int')
# mask[mask_nz] = 1

# %%
# np.allclose(mask,mask0)

# %%
B_train = B.copy()
B_train.shape
# B_train[mask > 0] = 0
# Out:
# (1, 500, 500)

# %%
importlib.reload(adet)
importlib.reload(tl)
# Out:
# <module 'tools' from '/Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/Reciprocity_Anomaly/code_new/tools.py'>

# %%
# %%time
flag_anomaly = False 
mask_input = np.logical_not(mask)
# mask_input = None 
flag_2step_em = False
pibr0 = theta['pi']
mupr0= theta['mu']
eta0 = 100
max_iter = 500

model = adet.AnomalyDetection(N=N,K=K,N_real=1, undirected=False, initialization=1, ag=2.5,bg=15.
                              ,use_approximation= False,out_folder='../data/output/5-fold_cv/synthetic/'
                              ,pibr0 = pibr0, mupr0= mupr0,eta0= eta0
                              ,in_parameters = dir1+'theta_'+label.split('syn_')[-1]
                              ,fix_eta=False,fix_communities=False,fix_w=True,fix_pibr=False,fix_mupr=False
                              ,plot_loglik=True,verbose=False, flag_anomaly = flag_anomaly
                              ,end_file = '.dat',constrained=False,assortative=True,out_inference=False
                              ,flag_2step_em = flag_2step_em, max_iter=max_iter, rseed =1000)

u,v,w,eta,pi,mu,maxL = model.fit(data=B_train,nodes=nodes,mask = None)
# Out:
# 500 3
# CPU times: user 6.74 s, sys: 34.3 ms, total: 6.77 s
# Wall time: 6.77 s

# %%
print('\nInferred eta: {}, true eta: {}.\n'.format(eta,theta['eta']))
print('\nInferred mu: {}, true mu: {}.\n'.format(mu,theta['mu']))
print('\nInferred pi: {}, true pi: {}.\n'.format(pi,theta['pi']))
print((maxL))
# Out:
# Inferred eta: 12.014612766716876, true eta: 1.
#
#
# Inferred mu: 0.0, true mu: 0.20831663326653307.
#
#
# Inferred pi: 0.0, true pi: 0.4.
#
# -53635.18022752275

# %%
w
# Out:
# array([[0.32679479, 0.05750347, 0.47514143]])

# %% [markdown]
# ### Cosine Similarity

# %%
u1, cs_u = cvfun.cosine_similarity(u,theta['u'])
v1, cs_v = cvfun.cosine_similarity(v,theta['v'])
cs_u,cs_v
# Out:
# (0.5416475772861358, 0.5482360275799437)

# %%
u1 = cvfun.normalize_nonzero_membership(u)
v1 = cvfun.normalize_nonzero_membership(v)
    
f1_u = cvfun.evalu(u1,theta['u'], 'f1')
f1_v = cvfun.evalu(v1,theta['v'], 'f1')
f1_u,f1_v
# Out:
# (0.3917, 0.3902)

# %% [markdown]
# ### AUC
# - $(A,\hat{A})$
# - $(Q,\sigma)$

# %%
importlib.reload(cvfun)
# Out:
# <module 'cv_functions' from '/Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/Reciprocity_Anomaly/code_new/cv_functions.py'>

# %%
M0 = cvfun.lambda0_full(u, v, w)
if flag_anomaly == False:
    Q = np.zeros_like(M0)
else:
    Q = cvfun.calculate_Q_dense(B,M0,eta,pi,mu)
M = cvfun.calculate_expectation(u,v,w,Q[0],eta,pi)

Q = cvfun.calculate_Q_dense(B,M0,eta,pi,mu)

plt.figure(figsize=(6,4)) 
plt.imshow(Q[0], cmap=cmap, interpolation='nearest') 
cax = plt.axes([0.85, 0.1, 0.075, 0.8])
plt.colorbar(cax=cax)
plt.title('Q')
plt.show()
print('max(Q),min(Q):', np.max(Q[0]), np.min(Q[0]))
# Out:
# max(Q),min(Q): 0.5087642152826272 0.0003350186319760919

# %% [markdown]
# ## AUC: Conditional and Marginal

# %%
importlib.reload(cvfun)
# Out:
# <module 'cv_functions' from '/Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/Reciprocity_Anomaly/code_new/cv_functions.py'>

# %%
M_marginal, M_conditional = cvfun.expected_computation(B=B, U=u, V=v, W=w, eta=eta, mu = mu, pi = pi)

# %%
print(cvfun.calculate_AUC(M_marginal[0], B[0], mask=None),cvfun.calculate_AUC(M_marginal[0], B[0], mask=None))
# Out:
# 0.5677484690435032 0.5677484690435032

# %%
print(cvfun.calculate_AUC(M_conditional[0], B[0], mask=None),cvfun.calculate_AUC(M_conditional[0], B[0], mask=None))
# Out:
# 0.6488382860728461 0.6488382860728461

# %%
mask_input = np.logical_not(mask)
mask_input = None

# %%
# maskQ = np.logical_and(mask[0]>0,B[0]>0)
# cvfun.calculate_AUC(M[0], B[0], mask=mask[0]),cvfun.calculate_AUC(Q[0], theta['sigma'], mask=maskQ)

# %%
cvfun.calculate_AUC(M[0], B[0], mask=None)
# Out:
# 0.7259244650711043

# %%
cvfun.calculate_AUC(Q[0], theta['sigma'], mask=None)
# Out:
# 0.26186778879192646

# %%
# f1 = cvfun.calculate_f1_score(Q,theta['sigma'], mask = maskQ)
# f1

# %%
f1 = cvfun.calculate_f1_score(Q,theta['sigma'], mask = None)
f1
# Out:
# 0.0040015005627110165

# %% [markdown]
# ### Q vs $\sigma$

# %%
cmap = 'PuBuGn'

# %%
mask_tmp = np.zeros(B[0].shape)
mask_tmp[B[0] > 0] = 1 

threshold = np.max(Q[0]*mask_tmp) * 0.9

z_pred = np.copy(Q[0]*mask_tmp)
if threshold > 0:
    z_pred[z_pred<threshold] = 0
    z_pred[z_pred>=threshold] = 1

plt.figure(figsize=(15,6))
plt.subplot(1, 3, 1)
plt.imshow(theta['sigma'], cmap=cmap, interpolation='nearest')
# plt.imshow(B[0], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('theta[sigma]')


plt.subplot(1, 3, 2)
plt.imshow(B[0], cmap=cmap, interpolation='nearest') #values of Q at entries of B
plt.colorbar(fraction=0.046)
plt.title('B')

plt.subplot(1, 3, 3)
plt.imshow(z_pred, cmap=cmap, interpolation='nearest') #values of Q at entries of B above a threshold 
plt.colorbar(fraction=0.046)
plt.title('sigma_pred')


plt.show()

# %%
cvfun.calculate_AUC(Q[0]*mask_tmp, theta['sigma']*mask_tmp, mask=None)
# Out:
# 0.4031248169748751

# %%
plt.figure(figsize=(6,4)) 
plt.imshow(Q[0]*mask_tmp, cmap=cmap, interpolation='nearest') 
cax = plt.axes([0.85, 0.1, 0.075, 0.8])
plt.colorbar(cax=cax)
plt.title('Q')
plt.show()

# %% [markdown]
# ### Cosine Similarity

# %%
u1, cs_u = cvfun.cosine_similarity(u,theta['u'])
v1, cs_v = cvfun.cosine_similarity(v,theta['v'])
cs_u,cs_v
# Out:
# (0.791118347604571, 0.7927793854270376)

# %%
u1 = cvfun.normalize_nonzero_membership(u)
v1 = cvfun.normalize_nonzero_membership(v)
    
f1_u = cvfun.evalu(u1,theta['u'], 'f1')
f1_v = cvfun.evalu(v1,theta['v'], 'f1')
f1_u,f1_v
# Out:
# (0.7564, 0.7772)

# %% [markdown]
# ### Ground truth communities

# %%
pos = nx.spring_layout(A[0]) 
umax=np.argmax(theta['u'],1)#max of each u
# plt.figure(figsize=(14,10))
nodelist = []
for k in range(K+1):
    nodelist.extend([i for i in range(N) if umax[i]==k])

# %%
pos = nx.spring_layout(A[0], seed = 10) 
umax=np.argmax(theta['u'],1)#max of each u
# plt.figure(figsize=(14,10))
nodelist = []
for k in range(K+1):
    nodelist.extend([i for i in range(N) if umax[i]==k])
    
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,8))
ax = axes.flatten()

nx.draw(A[0],pos=pos, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[0])
ax[0].set_axis_off()

umax=np.argmax(u,1)#max of each u

nx.draw(A[0],pos=pos, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[1])

plt.show()

# %% [markdown]
# ### A vs M

# %%
plt.figure(figsize=(16,5))
plt.subplot(1, 3, 1)
plt.imshow(B[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest')
# plt.imshow(B[0], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('A')


plt.subplot(1, 3, 2)
plt.imshow(M_marginal[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest') #values of Q at entries of B
plt.colorbar(fraction=0.046)
plt.title('Marginal')

plt.subplot(1, 3, 3)
plt.imshow(M_conditional[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest') #values of Q at entries of B above a threshold 
plt.colorbar(fraction=0.046)
plt.title('Conditional')


plt.show()

# %% [markdown]
# ### A vs M

# %%
# plt.figure(figsize=(14,8))
# plt.subplot(1, 2, 1)
# plt.imshow(B[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest')
# plt.colorbar(fraction=0.046)
# plt.title('A')
# plt.subplot(1, 2, 2)
# plt.imshow(M[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest')
# plt.colorbar(fraction=0.046)
# plt.title('<A>')
# plt.show()

# %% [markdown]
# ### W

# %%
plt.figure(figsize=(12,8))
plt.subplot(1, 2, 1)
plt.imshow(theta['w'][0], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('w')
plt.subplot(1, 2, 2)
try:
    plt.imshow(w[0], cmap=cmap, interpolation='nearest')
except:
    plt.imshow(np.diag(w[0]), cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('<w>')
plt.show()
