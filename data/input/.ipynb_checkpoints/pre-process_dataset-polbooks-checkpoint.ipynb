# %% [markdown]
# ### Pre-process polbooks datasets
# Goal : make input files/ polbooks dataset suitable for the algorithm.

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# import wget

# %%
# %matplotlib notebook

# %%
cmap = 'PuBuGn'

# %%
def reciprocal_edges(G):
    N=G.number_of_nodes()
    nodes=list(G.nodes())
    edges=G.edges()
    unique_edges=[]
    reciprocal_list=[]
    for idxi in range(N):
        i=nodes[idxi]
        for idxj in range(idxi+1,N):
            j=nodes[idxj]
            if (i,j) in edges or (j,i) in edges: 
                unique_edges.append((i,j))
                if (i,j) in edges and (j,i) in edges: 
                    reciprocal_list.append((i,j))

    unique_edges = list(set(unique_edges))
    reciprocal = len(reciprocal_list)
 
    print("reciprocal:", reciprocal,len(unique_edges),"reciprocity:",reciprocal/float(len(unique_edges)),reciprocal/float(len(unique_edges)+reciprocal)) 
    return  unique_edges, reciprocal_list

# %%
# !pwd
# Out:
# /Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/data/input

# %%
# !ls

# %%
outnet = 'polbooks'
H = nx.read_gml("polbooks/polbooks.gml")
edge_list = H.edges 
node_list = H.nodes(data=True)

# %% [markdown]
# ### Build multigraph

# %%
G = nx.DiGraph()
G.add_edges_from(edge_list) # or G.add_edges_from(edge_list)
G.add_nodes_from(H.nodes(data=True))

# %%
# list(G.edges(data=True))[:5]

# %%
for idx,nd in enumerate(list(G.nodes(data=True))):
    print(idx,nd)
# Out:
# 0 ('1000 Years for Revenge', {'value': 'n', 'com': 'n'})
# 1 ('Bush vs. the Beltway', {'value': 'c', 'com': 'c'})
# 2 ("Charlie Wilson's War", {'value': 'c', 'com': 'c'})
# 3 ('Losing Bin Laden', {'value': 'c', 'com': 'c'})
# 4 ('Sleeping With the Devil', {'value': 'n', 'com': 'n'})
# 5 ('The Man Who Warned America', {'value': 'c', 'com': 'c'})
# 6 ('Why America Slept', {'value': 'n', 'com': 'n'})
# 7 ('Ghost Wars', {'value': 'n', 'com': 'n'})
# 8 ('A National Party No More', {'value': 'c', 'com': 'c'})
# 9 ('Bush Country', {'value': 'c', 'com': 'c'})
# 10 ('Dereliction of Duty', {'value': 'c', 'com': 'c'})
# 11 ('Legacy', {'value': 'c', 'com': 'c'})
# 12 ('Off with Their Heads', {'value': 'c', 'com': 'c'})
# 13 ('Persecution', {'value': 'c', 'com': 'c'})
# 14 ("Rumsfeld's War", {'value': 'c', 'com': 'c'})
# 15 ('Breakdown', {'value': 'c', 'com': 'c'})
# 16 ('Betrayal', {'value': 'c', 'com': 'c'})
# 17 ('Shut Up and Sing', {'value': 'c', 'com': 'c'})
# 18 ('Meant To Be', {'value': 'n', 'com': 'n'})
# 19 ('The Right Man', {'value': 'c', 'com': 'c'})
# 20 ('Ten Minutes from Normal', {'value': 'c', 'com': 'c'})
# 21 ("Hillary's Scheme", {'value': 'c', 'com': 'c'})
# 22 ('The French Betrayal of America', {'value': 'c', 'com': 'c'})
# 23 ('Tales from the Left Coast', {'value': 'c', 'com': 'c'})
# 24 ('Hating America', {'value': 'c', 'com': 'c'})
# 25 ('The Third Terrorist', {'value': 'c', 'com': 'c'})
# 26 ('Endgame', {'value': 'c', 'com': 'c'})
# 27 ('Spin Sisters', {'value': 'c', 'com': 'c'})
# 28 ("All the Shah's Men", {'value': 'n', 'com': 'n'})
# 29 ('Dangerous Dimplomacy', {'value': 'c', 'com': 'c'})
# 30 ('The Price of Loyalty', {'value': 'l', 'com': 'l'})
# 31 ('House of Bush, House of Saud', {'value': 'l', 'com': 'l'})
# 32 ('Rise of the Vulcans', {'value': 'c', 'com': 'c'})
# 33 ('Against All Enemies', {'value': 'l', 'com': 'l'})
# 34 ('Disarming Iraq', {'value': 'l', 'com': 'l'})
# 35 ('The Death of Right and Wrong', {'value': 'c', 'com': 'c'})
# 36 ('Useful Idiots', {'value': 'c', 'com': 'c'})
# 37 ('Let Freedom Ring', {'value': 'c', 'com': 'c'})
# 38 ('Bias', {'value': 'c', 'com': 'c'})
# 39 ('Deliver Us from Evil', {'value': 'c', 'com': 'c'})
# 40 ('Give Me a Break', {'value': 'c', 'com': 'c'})
# 41 ('The Enemy Within', {'value': 'c', 'com': 'c'})
# 42 ('The Real America', {'value': 'c', 'com': 'c'})
# 43 ("Who's Looking Out for You?", {'value': 'c', 'com': 'c'})
# 44 ('The Official Handbook Vast Right Wing Conspiracy', {'value': 'c', 'com': 'c'})
# 45 ('Power Plays', {'value': 'n', 'com': 'n'})
# 46 ('Arrogance', {'value': 'c', 'com': 'c'})
# 47 ('The Perfect Wife', {'value': 'n', 'com': 'n'})
# 48 ('The Bushes', {'value': 'c', 'com': 'c'})
# 49 ('Things Worth Fighting For', {'value': 'c', 'com': 'c'})
# 50 ('Surprise, Security, the American Experience', {'value': 'n', 'com': 'n'})
# 51 ('Allies', {'value': 'c', 'com': 'c'})
# 52 ('Slander', {'value': 'c', 'com': 'c'})
# 53 ('The Savage Nation', {'value': 'c', 'com': 'c'})
# 54 ('Fighting Back', {'value': 'c', 'com': 'c'})
# 55 ('We Will Prevail', {'value': 'c', 'com': 'c'})
# 56 ('Those Who Trespass', {'value': 'c', 'com': 'c'})
# 57 ('Hollywood Interrupted', {'value': 'c', 'com': 'c'})
# 58 ('The Faith of George W Bush', {'value': 'c', 'com': 'c'})
# 59 ('Bush at War', {'value': 'c', 'com': 'c'})
# 60 ('Why Courage Matters', {'value': 'c', 'com': 'c'})
# 61 ('The Great Unraveling', {'value': 'l', 'com': 'l'})
# 62 ('American Dynasty', {'value': 'l', 'com': 'l'})
# 63 ('Rogue Nation', {'value': 'l', 'com': 'l'})
# 64 ('The Sorrows of Empire', {'value': 'l', 'com': 'l'})
# 65 ('Big Lies', {'value': 'l', 'com': 'l'})
# 66 ('The Lies of George W. Bush', {'value': 'l', 'com': 'l'})
# 67 ('Worse Than Watergate', {'value': 'l', 'com': 'l'})
# 68 ('Plan of Attack', {'value': 'n', 'com': 'n'})
# 69 ('Bushwomen', {'value': 'l', 'com': 'l'})
# 70 ('The Bubble of American Supremacy', {'value': 'l', 'com': 'l'})
# 71 ('The Politics of Truth', {'value': 'l', 'com': 'l'})
# 72 ('Fanatics and Fools', {'value': 'l', 'com': 'l'})
# 73 ('Bushwhacked', {'value': 'l', 'com': 'l'})
# 74 ('Lies and the Lying Liars Who Tell Them', {'value': 'l', 'com': 'l'})
# 75 ('Had Enough?', {'value': 'l', 'com': 'l'})
# 76 ("Dude, Where's My Country?", {'value': 'l', 'com': 'l'})
# 77 ('The New Pearl Harbor', {'value': 'l', 'com': 'l'})
# 78 ('The Exception to the Rulers', {'value': 'l', 'com': 'l'})
# 79 ("The O'Reilly Factor", {'value': 'c', 'com': 'c'})
# 80 ('Buck Up Suck Up', {'value': 'l', 'com': 'l'})
# 81 ('America Unbound', {'value': 'l', 'com': 'l'})
# 82 ('The Choice', {'value': 'l', 'com': 'l'})
# 83 ('Colossus', {'value': 'n', 'com': 'n'})
# 84 ('Soft Power', {'value': 'l', 'com': 'l'})
# 85 ('Downsize This!', {'value': 'l', 'com': 'l'})
# 86 ('Stupid White Men', {'value': 'l', 'com': 'l'})
# 87 ('Rush Limbaugh Is a Big Fat Idiot', {'value': 'l', 'com': 'l'})
# 88 ('The Best Democracy Money Can Buy', {'value': 'l', 'com': 'l'})
# 89 ('The Culture of Fear', {'value': 'l', 'com': 'l'})
# 90 ("We're Right They're Wrong", {'value': 'l', 'com': 'l'})
# 91 ('Shrub', {'value': 'l', 'com': 'l'})
# 92 ('Thieves in High Places', {'value': 'l', 'com': 'l'})
# 93 ('The Buying of the President 2004', {'value': 'l', 'com': 'l'})
# 94 ('Perfectly Legal', {'value': 'l', 'com': 'l'})
# 95 ('Hegemony or Survival', {'value': 'l', 'com': 'l'})
# 96 ('What Liberal Media?', {'value': 'l', 'com': 'l'})
# 97 ('The Clinton Wars', {'value': 'l', 'com': 'l'})
# 98 ('The Future of Freedom', {'value': 'n', 'com': 'n'})
# 99 ('Empire', {'value': 'n', 'com': 'n'})
# 100 ('Living History', {'value': 'l', 'com': 'l'})
# 101 ("MoveOn's 50 Ways to Love Your Country", {'value': 'l', 'com': 'l'})
# 102 ('Freethinkers', {'value': 'l', 'com': 'l'})
# 103 ("It's Still the Economy, Stupid!", {'value': 'l', 'com': 'l'})
# 104 ('Weapons of Mass Deception', {'value': 'l', 'com': 'l'})

# %%
val_list = list(G.nodes('value'))

# %%
for ii in val_list: 
    nx.set_node_attributes(G, {ii[0]: ii[1]}, name="com")

# %%
G.nodes['1000 Years for Revenge']["com"]
# Out:
# 'n'

# %%
G.number_of_nodes(),G.number_of_edges()
# Out:
# (105, 441)

# %%
G1 = nx.convert_node_labels_to_integers(G, first_label=0)

# %%
comm = [G1.nodes[cc]["com"] for cc in list(G1.nodes)]
comm
# Out:
# ['n',
#  'c',
#  'c',
#  'c',
#  'n',
#  'c',
#  'n',
#  'n',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'n',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'n',
#  'c',
#  'l',
#  'l',
#  'c',
#  'l',
#  'l',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'n',
#  'c',
#  'n',
#  'c',
#  'c',
#  'n',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'n',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'c',
#  'l',
#  'l',
#  'l',
#  'n',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l',
#  'n',
#  'n',
#  'l',
#  'l',
#  'l',
#  'l',
#  'l']

# %% [markdown]
# ### Remove self loops

# %%
G1.remove_edges_from(nx.selfloop_edges(G1))

# %%
G1.number_of_nodes(),G1.number_of_edges()
# Out:
# (105, 441)

# %% [markdown]
# ### Remove nodes that have few out- or in-coming edges

# %%
# outdegree = [ d[1] for d in list(G1.out_degree())]
# indegree = [ d[1] for d in list(G1.in_degree())]

# np.percentile(outdegree,50)

# %%
# G2=nx.DiGraph(G1)

# %%
# threshold=0

# Gnodes = list(G1.nodes())
# nodes_to_remove=[n for n in Gnodes if G1.out_degree(n)<threshold]
# nodes_to_remove.extend([n for n in Gnodes if G1.in_degree(n)<threshold])
# nodes_to_remove=list(set(nodes_to_remove))
# len(nodes_to_remove),len(Gnodes)

# G2.remove_nodes_from(list(nodes_to_remove))
# print(len(nodes_to_remove))

# %%
# G2.number_of_nodes(),G2.number_of_edges()

# %%
# ncc = nx.number_weakly_connected_components(G2)
# cc = list(nx.weakly_connected_components(G1))
# for c in range(ncc):
#     print(c,len(cc[c]))

# %%
# Gc = max(nx.weakly_connected_components(G2), key=len)
# Gc = cc[3]
# nodes_to_remove=set(G2.nodes()).difference(Gc)
# print("removed" ,len(nodes_to_remove),' nodes')
# G2.remove_nodes_from(list(nodes_to_remove))
# print(G2.number_of_nodes(),G2.number_of_edges())

# %%
# unique_edges, reciprocal_list = reciprocal_edges(G2)

# %%
G1nodes = list(G.nodes(data='True'))
# pos = nx.spring_layout(G1)

# %%
# # subG = np.random.choice(G1nodes,400)
# # k = G1.subgraph(subG)  
# k =G2

# plt.figure()
# nx.draw_networkx(k, pos=pos,with_labels=False,node_size=10)

# %%
node_color =[]
for node in G1.nodes(data=True):

    # if the node has the attribute group1
    if 'n' in node[1]['com']:
        node_color.append('blue')

    # if the node has the attribute group1
    elif 'c' in node[1]['com']:
        node_color.append('red')

    # if the node has the attribute group1
    elif 'l' in node[1]['com']:
        node_color.append('green')

# %%
cmap = 'PuBuGn'
umax= [G1.nodes[cc]["com"] for cc in list(G1.nodes)]
plt.figure(figsize=(8,6))
pos = nx.spring_layout(G1,seed=40)
nodelist = []
N = len(list(G1.nodes))
K = 3
# for k in range(K+1):
for k in ['n','c','l']:
    nodelist.extend([i for i in range(N) if umax[i]==k])
    
nx.draw(G1,pos=pos,arrows=False, with_labels=False,node_color = node_color,cmap = plt.cm.Pastel2, node_size=200)
# ax[0].set_axis_off()


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# nx.draw(G1)

# %% [markdown]
# ### Output on file

# %%
import pandas as pd
import numpy as np
df = nx.to_pandas_edgelist(G1)
df['w'] = 1
df.head(10)
# Out:
#    source  target  w
# 0       0       1  1
# 1       0       2  1
# 2       0       3  1
# 3       0       4  1
# 4       0       5  1
# 5       0       6  1
# 6       1       3  1
# 7       1       5  1
# 8       1       6  1
# 9       2       4  1

# %%
# G2 = nx.from_pandas_edgelist(G1.edges(), 'source', 'target', ['w'])

# %%
outfile = 'RD/'+outnet+'1.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
nx.write_weighted_edgelist(G2, outfile)
print(outfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6a2c9c7d2264> in <module>
#       1 outfile = 'RD/'+outnet+'1.dat'
#       2 # nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
# ----> 3 nx.write_weighted_edgelist(G2, outfile)
#       4 print(outfile)
#
# NameError: name 'G2' is not defined
