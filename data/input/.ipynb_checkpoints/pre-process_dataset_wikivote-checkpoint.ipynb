# %% [markdown]
# ### Pre-process datasets
# Goal : make input files suitable for the algorithm.

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# import wget

# %%
# %matplotlib notebook

# %%
def reciprocal_edges(G):
    N=G.number_of_nodes()
    nodes=list(G.nodes())
    edges=G.edges()
    unique_edges=[]
    reciprocal_list=[]
    for idxi in range(N):
        i=nodes[idxi]
        for idxj in range(idxi+1,N):
            j=nodes[idxj]
            if (i,j) in edges or (j,i) in edges: 
                unique_edges.append((i,j))
                if (i,j) in edges and (j,i) in edges: 
                    reciprocal_list.append((i,j))

    unique_edges = list(set(unique_edges))
    reciprocal = len(reciprocal_list)
 
    print("reciprocal:", reciprocal,len(unique_edges),"reciprocity:",reciprocal/float(len(unique_edges)),reciprocal/float(len(unique_edges)+reciprocal)) 
    return  unique_edges, reciprocal_list

# %%
# !pwd
# Out:
# /Users/hsafdari/Documents/Dr_Caterina_de_Bacco/anomaly_detection/data/input

# %%
# !ls
# Out:
# RD
# Wikipedia_vote_network
# airport.csv
# airports.dat
# data_description.md
# dutch2.dat
# dutch6.dat
# facebook-wosn-wall.dat
# pok_month0.dat
# polblogs
# polbooks
# pre-process_WikiTalkht.ipynb
# pre-process_dataset-POK0.ipynb
# pre-process_dataset-airports.ipynb
# pre-process_dataset-polblogs.ipynb
# pre-process_dataset-polbooks.ipynb
# pre-process_dataset-rewiring_polbooks.ipynb
# pre-process_dataset.ipynb
# pre-process_dataset_wikivote.ipynb
# pre-process_facebookwaall.ipynb
# syn_500_3_20.0_0.8_True_0.dat
# synthetic
# test.ipynb
# theta_500_3_20.0_0.8_True_0.npz
# twitter.dat
# u.dat
# u_syn.dat
# v.dat
# wiki_talk_ht.dat

# %%
outnet='Wikipedia_vote_network/'
input_data = pd.read_csv(outnet+'wiki-Vote.txt', header=None, sep='\s+')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c3ff5a1a4496> in <module>
#       1 outnet='Wikipedia_vote_network/'
# ----> 2 input_data = pd.read_csv(outnet+'wiki-Vote.txt', header=None, sep='\s+')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Wikipedia_vote_network/wiki-Vote.txt'

# %%
df = pd.DataFrame(input_data)
df.head(n=2)
# Out:
#    0  1
# 0  1  2
# 1  1  3

# %%
df[2] = 1
df.head(2)
# Out:
#    0  1  2
# 0  1  2  1
# 1  1  3  1

# %% [markdown]
# ### Remove 'E' from first column

# %%
# df=df.drop(0,axis=1)
# df.columns=[0,1,2]

# %%
df.head(n=2)
# Out:
#    0  1  2
# 0  1  2  1
# 1  1  3  1

# %%
df[2].unique()
# Out:
# array([1])

# %%
len(df)
# Out:
# 33101

# %% [markdown]
# ### Keep only some of the edges, based on the third column.
# For POK dataset, keep only one month of data.

# %%
# onemonth = 60*60*24*30
# df=input_data[input_data[2]<onemonth]
# len(df)

# %% [markdown]
# ### Keep only nodes that have at least one incoming and one outgoing edge

# %%
# ego=input_data[0].unique()
# alter=input_data[1].unique()
# df=input_data[input_data[0].isin(nodes)]

ego=df[0].unique()
alter=df[1].unique()
nodes = set(ego).intersection(set(alter))
print(len(nodes))

df=df[df[0].isin(nodes)]
df=df[df[1].isin(nodes)]
len(df)
# Out:
# 532
# 1266

# %% [markdown]
# ### Build multigraph

# %%
edge_list=[(n[0],n[1],len(g)) for n,g in df.groupby(by=[0,1])]

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from(edge_list) # or G.add_edges_from(edge_list)

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from(df.values)

# %%
list(G.edges(data=True))[:5]
# Out:
# [(1, 16, {'weight': 1}),
#  (1, 18, {'weight': 1}),
#  (1, 19, {'weight': 1}),
#  (1, 28, {'weight': 1}),
#  (1, 34, {'weight': 1})]

# %% [markdown]
# ### Remove self loops

# %%
G.remove_edges_from(list(nx.selfloop_edges(G)))
G.number_of_nodes(),G.number_of_edges()
# Out:
# (477, 1266)

# %%
G.out_degree()
# Out:
# OutMultiDegreeView({1: 11, 16: 8, 18: 4, 19: 3, 28: 4, 34: 0, 36: 2, 37: 2, 39: 3, 42: 2, 43: 4, 45: 2, 63: 4, 64: 3, 70: 3, 75: 6, 76: 4, 149: 3, 151: 4, 153: 2, 161: 5, 166: 3, 179: 2, 180: 1, 188: 0, 536: 2, 537: 8, 543: 3, 549: 2, 245: 0, 550: 0, 563: 2, 590: 2, 792: 11, 804: 8, 808: 4, 812: 2, 818: 3, 825: 10, 835: 2, 843: 7, 844: 10, 851: 5, 859: 3, 864: 5, 900: 1, 905: 6, 927: 4, 934: 6, 969: 3, 971: 1, 1081: 4, 1093: 3, 1095: 2, 1108: 2, 1110: 1, 1134: 7, 1189: 5, 1200: 2, 1301: 4, 1307: 3, 1371: 1, 1373: 5, 1529: 2, 1627: 1, 1639: 1, 1728: 1, 1731: 0, 1799: 8, 1803: 1, 1815: 2, 1824: 1, 1838: 1, 1895: 2, 1962: 0, 1965: 0, 1966: 1, 1971: 9, 990: 5, 1994: 3, 1996: 2, 2025: 4, 2028: 0, 2039: 0, 2040: 2, 2050: 2, 2073: 1, 2141: 2, 2190: 0, 2251: 6, 2385: 3, 2405: 3, 2411: 0, 2443: 7, 2461: 7, 2473: 0, 2488: 5, 2499: 0, 2501: 11, 2503: 2, 2506: 6, 2512: 1, 2515: 1, 2525: 2, 2536: 0, 2559: 1, 2598: 12, 2636: 7, 2639: 5, 2646: 9, 2652: 1, 2654: 1, 2658: 1, 2670: 6, 2677: 12, 2679: 18, 2710: 1, 2717: 8, 2802: 4, 3010: 6, 3016: 6, 3086: 3, 897: 2, 3141: 1, 3159: 3, 3177: 5, 3190: 1, 3202: 3, 3211: 1, 1368: 13, 3213: 4, 3220: 1, 3230: 3, 3265: 6, 3266: 6, 3385: 1, 3531: 3, 3567: 0, 3571: 1, 3632: 1, 3657: 0, 219: 0, 3772: 5, 3779: 5, 3792: 3, 3826: 2, 3898: 1, 3902: 1, 3957: 1, 3960: 0, 4107: 3, 4111: 3, 4120: 0, 4122: 0, 4171: 5, 4183: 0, 4192: 0, 4
, 13611: 1, 10117: 3, 13815: 2, 13823: 1, 13829: 2, 13858: 1, 13916: 0, 14247: 0, 11728: 0, 14390: 1, 14392: 0, 14411: 1, 14463: 1, 14483: 5, 14484: 4, 14494: 6, 14539: 2, 14543: 3, 14544: 2, 14545: 3, 14573: 2, 14916: 1, 14929: 3, 14947: 6, 14954: 4, 14956: 1, 14957: 7, 15092: 2, 15100: 4, 15198: 2, 4633: 0, 15369: 1, 2871: 2, 15481: 1, 15924: 1, 15929: 0, 15949: 4, 7083: 0, 13471: 3, 6112: 0, 16131: 1, 3283: 0, 5499: 0, 16294: 1, 16296: 1, 16297: 0, 8968: 0, 16332: 3, 14534: 1, 16382: 1, 5626: 2, 1256: 0, 16720: 1, 16790: 2, 16794: 0, 16795: 1, 4261: 0, 10138: 8, 16944: 1, 16945: 2, 16972: 1, 16982: 3, 1179: 3, 16043: 0, 17599: 0, 2926 ...

# %% [markdown]
# ### Remove nodes that have few out- or in-coming edges

# %%
outdegree = [ d[1] for d in list(G.out_degree())]
indegree = [ d[1] for d in list(G.in_degree())]

np.percentile(outdegree,50)
# Out:
# 2.0

# %%
G1=nx.MultiDiGraph(G)

# %%
threshold=0

Gnodes = list(G.nodes())
nodes_to_remove=[n for n in Gnodes if G.out_degree(n)<threshold]
nodes_to_remove.extend([n for n in Gnodes if G.in_degree(n)<threshold])
nodes_to_remove=list(set(nodes_to_remove))
len(nodes_to_remove),len(Gnodes)

G1.remove_nodes_from(list(nodes_to_remove))
print(len(nodes_to_remove))
# Out:
# 0

# %%
G1.number_of_nodes(),G1.number_of_edges()
# Out:
# (477, 1266)

# %%
ncc = nx.number_weakly_connected_components(G1)
cc = list(nx.weakly_connected_components(G))
for c in range(ncc):
    print(c,len(cc[c]))
# Out:
# 0 426
# 1 2
# 2 9
# 3 6
# 4 3
# 5 2
# 6 2
# 7 2
# 8 2
# 9 3
# 10 2
# 11 3
# 12 5
# 13 2
# 14 2
# 15 3
# 16 3

# %%
Gc = max(nx.weakly_connected_components(G1), key=len)
Gc = cc[3]
nodes_to_remove=set(G1.nodes()).difference(Gc)
print("removed" ,len(nodes_to_remove),' nodes')
G1.remove_nodes_from(list(nodes_to_remove))
print(G1.number_of_nodes(),G1.number_of_edges())
# Out:
# removed 471  nodes
# 6 14

# %%
unique_edges, reciprocal_list = reciprocal_edges(G1)
# Out:
# reciprocal: 5 9 reciprocity: 0.5555555555555556 0.35714285714285715

# %%
G1nodes = list(G1.nodes())
pos = nx.spring_layout(G1)

# %%
# subG = np.random.choice(G1nodes,400)
# k = G1.subgraph(subG)  
k =G1

plt.figure()
nx.draw_networkx(k, pos=pos,with_labels=False,node_size=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# nx.draw(G1)

# %% [markdown]
# ### Output on file

# %%
outfile = 'RD/'+outnet+'.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
nx.write_weighted_edgelist(G, outfile)
print(outfile)
# Out:
# RD/twitter_pr.dat
