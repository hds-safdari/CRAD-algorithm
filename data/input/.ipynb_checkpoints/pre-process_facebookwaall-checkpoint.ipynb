# %% [markdown]
# ### Pre-process datasets
# Goal : make input files suitable for the algorithm.

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# import wget

# %%
# %matplotlib notebook

# %%
def reciprocal_edges(G):
    N=G.number_of_nodes()
    nodes=list(G.nodes())
    edges=G.edges()
    unique_edges=[]
    reciprocal_list=[]
    for idxi in range(N):
        i=nodes[idxi]
        for idxj in range(idxi+1,N):
            j=nodes[idxj]
            if (i,j) in edges or (j,i) in edges: 
                unique_edges.append((i,j))
                if (i,j) in edges and (j,i) in edges: 
                    reciprocal_list.append((i,j))

    unique_edges = list(set(unique_edges))
    reciprocal = len(reciprocal_list)
 
    print("reciprocal:", reciprocal,len(unique_edges),"reciprocity:",reciprocal/float(len(unique_edges)),reciprocal/float(len(unique_edges)+reciprocal)) 
    return  unique_edges, reciprocal_list

# %%
# !pwd
# Out:
# /Users/hsafdari/Dropbox/Dr_Caterina_de_Bacco/anomaly detection/data/input

# %%
# !ls
# Out:
# RD                              pre-process_facebookwaall.ipynb
# data_description.md             syn_500_3_20.0_0.8_True_0.dat
# dutch2.dat                      synthetic
# dutch6.dat                      theta_500_3_20.0_0.8_True_0.npz
# facebook-wosn-wall.dat          twitter.dat
# pre-process_WikiTalkht.ipynb    wiki_talk_ht.dat
# pre-process_dataset.ipynb

# %%
outnet='facebook-wosn-wall'
input_data = pd.read_csv(outnet+'.dat', header=None, sep='\s+')

# %%
df = pd.DataFrame(input_data)
df.head(n=2)
# Out:
#    0  1  2           3
# 0  1  1  1  1095135831
# 1  2  3  1  1097725406

# %%
# df[2] = 1
# df.head(2)

# %% [markdown]
# ### Remove 'E' from first column

# %%
# df=df.drop(0,axis=1)
# df.columns=[0,1,2]

# %%
df.head(n=2)
# Out:
#    0  1  2           3
# 0  1  1  1  1095135831
# 1  2  3  1  1097725406

# %%
df.drop([3], axis=1, inplace=True)

# %%
df[2].unique()
# Out:
# array([1])

# %%
len(df)
# Out:
# 876993

# %% [markdown]
# ### Keep only some of the edges, based on the third column.
# For POK dataset, keep only one month of data.

# %%
# onemonth = 60*60*24*30
# df=input_data[input_data[2]<onemonth]
# len(df)

# %% [markdown]
# ### Keep only nodes that have at least one incoming and one outgoing edge

# %%
# ego=input_data[0].unique()
# alter=input_data[1].unique()
# df=input_data[input_data[0].isin(nodes)]

ego=df[0].unique()
alter=df[1].unique()
nodes = set(ego).intersection(set(alter))
print(len(nodes))

df=df[df[0].isin(nodes)]
df=df[df[1].isin(nodes)]
len(df)
# Out:
# 35424
# 768246

# %%
df.head()
# Out:
#    0  1  2
# 0  1  1  1
# 1  2  3  1
# 2  4  4  1
# 3  5  5  1
# 4  2  3  1

# %% [markdown]
# ### Build multigraph

# %%
edge_list=[(n[0],n[1],len(g)) for n,g in df.groupby(by=[0,1])]

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from(edge_list) # or G.add_edges_from(edge_list)

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from(df.values)

# %%
list(G.edges(data=True))[:5]
# Out:
# [(1, 1, {'weight': 1}),
#  (2, 3, {'weight': 1}),
#  (2, 3, {'weight': 1}),
#  (2, 3, {'weight': 1}),
#  (2, 3, {'weight': 1})]

# %% [markdown]
# ### Remove self loops

# %%
G.remove_edges_from(list(nx.selfloop_edges(G)))
G.number_of_nodes(),G.number_of_edges()
# Out:
# (35358, 746795)

# %%
G.out_degree()
# Out:
# OutMultiDegreeView({1: 0, 2: 105, 3: 8, 4: 0, 5: 417, 6: 10, 9: 54, 10: 92, 11: 0, 12: 1, 13: 104, 14: 61, 15: 42, 16: 102, 19: 49, 20: 25, 17: 141, 21: 178, 22: 35, 23: 118, 24: 65, 27: 172, 28: 139, 29: 98, 30: 18, 31: 28, 32: 30, 33: 11, 34: 16, 35: 22, 36: 52, 37: 32, 38: 24, 39: 22, 40: 83, 43: 3, 44: 106, 45: 81, 46: 65, 47: 31, 48: 34, 49: 56, 50: 35, 51: 9, 52: 13, 53: 7, 54: 74, 55: 3, 56: 15, 57: 26, 58: 47, 59: 78, 60: 10, 61: 22, 62: 81, 63: 13, 64: 69, 65: 126, 66: 17, 68: 79, 69: 9, 70: 191, 71: 73, 72: 69, 73: 11, 74: 16, 75: 67, 76: 70, 77: 25, 78: 17, 79: 7, 80: 44, 81: 41, 82: 73, 83: 7, 84: 75, 85: 25, 86: 40, 87: 47, 88: 38, 89: 102, 90: 24, 91: 37, 92: 62, 93: 19, 94: 0, 95: 148, 96: 5, 97: 10, 98: 69, 99: 33, 100: 12, 101: 13, 102: 3, 103: 9, 104: 15, 105: 4, 106: 11, 107: 37, 108: 13, 109: 42, 110: 90, 111: 10, 112: 5, 113: 6, 114: 8, 115: 40, 116: 20, 117: 3, 118: 19, 119: 27, 120: 0, 41: 15, 121: 17, 122: 2, 123: 102, 124: 66, 127: 4, 128: 13, 129: 43, 130: 20, 132: 19, 133: 26, 134: 51, 135: 11, 136: 4, 137: 21, 138: 8, 139: 62, 142: 33, 143: 12, 144: 38, 146: 4, 147: 15, 148: 6, 149: 12, 150: 95, 155: 54, 156: 55, 157: 16, 158: 29, 159: 286, 160: 54, 163: 29, 164: 26, 165: 12, 166: 100, 167: 73, 170: 29, 171: 6, 172: 43, 173: 92, 174: 11, 175: 1, 176: 13, 177: 6, 178: 21, 179: 2, 180: 23, 181: 42, 182: 21, 183: 12, 184: 43, 185: 139, 186: 153, 187: 22, 188: 22, 189: 5, 190: 97, 191: 18, 192: 22, 193: 24, 194: 42, 195: 33, 196: 7, 197: 7, 198: 6, 199: 0, 200: 54, 201: 3, 202: 10, 204: 44, 205: 135, 206: 35, 207: 148, 208: 50, 209: 28, 210: 49, 211: 44, 212: 37, 213: 36, 214: 29, 215: 0, 216: 42, 217: 8, 218: 45, 219: 34, 220: 71, 221: 138, 222: 168, 223: 6, 224: 8, 225: 22, 227: 43, 228: 42, 229: 101, 230: 2, 231: 10, 232: 56, 233: 7, 234: 21, 235: 13, 236: 8, 237: 48, 238: 98, 239: 54, 240: 42, 241: 227, 242: 149, 243: 148, 244: 0, 247: 15, 248: 9, 249: 43, 250: 22, 251: 28, 252: 88, 253: 47, 254: 39, 255: 9, 256: 6, 257: 94, 258: 4, 259: 52, 260: 77, 261: 120, 262: 40, 263: 5, 264: 42, 265: 216, 266: 127, 267: 12, 268: 5, 269: 31, 270: 27, 246: 40, 271: 418, 272: 0, 273: 10, 274: 66, 275: 101, 276: 14, 277: 73, 278: 40, 279: 7, 280: 20, 283: 62, 284: 10, 285: 33, 286: 17, 287: 42, 288: 15, 289: 1, 290: 14, 291: 9, 294: 228, 295: 120, 296: 55, 297: 0, 298: 5, 299: 56, 300: 17, 301: 17, 302: 27, 305: 23, 306: 1, 307: 5, 308: 22, 309: 6, 310: 11, 311: 23, 312: 16, 313: 22, 314: 73, 315: 3, 318: 22, 319: 62, 320: 67, 321: 66, 140: 70, 322: 51, 323: 66, 324: 1, 327: 5, 328: 272, 329: 41, 335: 1, 336: 28, 337: 1, 338: 5, 339: 7, 340: 4, 341: 32, 342: 80, 343: 6, 344: 97, 345: 57, 346: 4, 347: 10, 348: 0, 349: 43, 350: 0, 303: 36, 352: 15, 353: 5, 354: 1, 357: 66, 358: 10, 359: 23, 360: 2, 361: 17, 362: 9, 363: 58, 364: 54, 365: 16, 366: 85, 367: 6, 368: 28, 369: 11, 370: 185, 371: 257, 372: 7, 373: 10, 374: 76, 375: 132, 376: 3, 377: 5, 378: 26, 379: 57, 380: 55, 381: 0, 382: 139, 383: 88, 384: 50, 385: 134, 386: 52, 387: 202, 389: 97, 390: 36, 391: 75, 392: 12, 393: 26, 394: 12, 395: 262, 396: 7, 397: 10, 398: 16, 399: 46, 293: 20, 400: 115, 401: 28, 402: 29, 403: 3, 404: 6, 405: 0, 406: 54, 407: 0, 408: 65, 409: 5, 410: 14, 411: 11, 125: 6, 412: 51, 413: 6, 414: 73, 417: 25, 418: 63, 419: 84, 420: 90, 421: 3, 423: 71, 424: 99, 425: 247, 426: 121, 427: 68, 428: 77, 429: 19, 430: 15, 431: 83, 432: 23, 433: 28, 434: 18, 435: 116, 437: 124, 439: 39, 440: 17, 416: 29, 441: 110, 442: 22, 443: 7, 444: 27, 445: 10, 446: 2, 447: 235, 448: 7, 449: 25, 450: 6, 451: 36, 452: 19, 453: 180, 454: 20, 455: 53, 457: 5, 458: 28, 459: 24, 460: 47, 461: 10, 462: 2, 463: 15, 464: 44, 467: 85, 468: 11, 469: 27, 470: 12, 471: 24, 472: 95, 473: 3, 474: 9, 475: 43, 476: 43, 477: 41, 478: 116, 479: 7, 480: 16, 481: 15, 482: 48, 483: 102, 484: 81, 485: 50, 486: 29, 487: 30, 488: 55, 489: 24, 490: 172, 491: 7, 492: 49, 493: 23, 494: 27, 495: 10, 496: 142, 497: 11, 498: 1, 499: 10, 502: 34, 503: 48, 504: 29, 505: 35, 506: 20, 507:  ...

# %% [markdown]
# ### Remove nodes that have few out- or in-coming edges

# %%
outdegree = [ d[1] for d in list(G.out_degree())]
indegree = [ d[1] for d in list(G.in_degree())]

np.percentile(outdegree,50)
# Out:
# 7.0

# %%
G1=nx.MultiDiGraph(G)

# %%
threshold=2

Gnodes = list(G.nodes())
nodes_to_remove=[n for n in Gnodes if G.out_degree(n)<threshold]
nodes_to_remove.extend([n for n in Gnodes if G.in_degree(n)<threshold])
nodes_to_remove=list(set(nodes_to_remove))
len(nodes_to_remove),len(Gnodes)

G1.remove_nodes_from(list(nodes_to_remove))
print(len(nodes_to_remove))
# Out:
# 9076

# %%
G1.number_of_nodes(),G1.number_of_edges()
# Out:
# (26282, 717339)

# %%
ncc = nx.number_weakly_connected_components(G1)
cc = list(nx.weakly_connected_components(G))
for c in range(ncc):
    print(c,len(cc[c]))
# Out:
# 0 1
# 1 33148
# 2 1
# 3 1
# 4 1
# 5 1
# 6 3
# 7 1
# 8 1
# 9 1
# 10 2
# 11 1
# 12 1
# 13 1
# 14 1
# 15 1
# 16 1
# 17 1
# 18 1
# 19 1
# 20 1
# 21 2
# 22 1
# 23 1
# 24 1
# 25 1
# 26 1
# 27 1
# 28 1
# 29 1
# 30 1
# 31 1
# 32 1
# 33 1
# 34 1
# 35 1
# 36 2
# 37 1
# 38 1
# 39 1
# 40 1
# 41 2
# 42 1
# 43 1
# 44 1
# 45 1
# 46 1
# 47 1
# 48 1
# 49 1
# 50 1
# 51 3
# 52 1
# 53 1
# 54 1
# 55 1
# 56 1
# 57 1
# 58 3
# 59 1
# 60 1
# 61 1
# 62 1
# 63 1
# 64 1
# 65 2
# 66 2
# 67 1
# 68 1
# 69 1
# 70 1
# 71 2
# 72 1
# 73 1
# 74 1
# 75 1
# 76 1
# 77 1
# 78 1
# 79 3
# 80 1
# 81 1
# 82 2
# 83 1
# 84 3
# 85 1
# 86 1
# 87 1
# 88 1
# 89 1
# 90 1
# 91 1
# 92 1
# 93 1
# 94 1
# 95 1
# 96 1
# 97 1
# 98 1
# 99 1
# 100 4
# 101 2
# 102 1
# 103 1
# 104 1
# 105 1
# 106 1
# 107 1
# 108 1
# 109 1
# 110 1
# 111 1
# 112 1
# 113 1
# 114 1
# 115 1
# 116 1
# 117 1
# 118 1
# 119 1
# 120 1
# 121 1
# 122 1
# 123 1
# 124 1
# 125 2
# 126 1
# 127 1
# 128 1
# 129 1
# 130 1
# 131 1
# 132 1
# 133 1
# 134 3
# 135 1
# 136 1
# 137 1
# 138 2
# 139 1
# 140 1
# 141 1
# 142 1
# 143 1
# 144 1
# 145 2
# 146 1
# 147 1
# 148 2
# 149 1
# 150 1
# 151 1
# 152 1
# 153 1
# 154 1
# 155 1
# 156 1
# 157 1
# 158 1
# 159 2
# 160 1
# 161 1
# 162 1
# 163 1
# 164 2
# 165 1
# 166 1
# 167 1
# 168 1
# 169 2
# 170 1
# 171 1
# 172 1
# 173 1
# 174 1
# 175 1
# 176 1
# 177 1
# 178 2
# 179 2
# 180 1
# 181 1
# 182 1
# 183 1
# 184 1
# 185 1
# 186 1
# 187 1
# 188 1
# 189 1
# 190 1
# 191 1

# %%
Gc = max(nx.weakly_connected_components(G1), key=len)
Gc = cc[3]
nodes_to_remove=set(G1.nodes()).difference(Gc)
print("removed" ,len(nodes_to_remove),' nodes')
G1.remove_nodes_from(list(nodes_to_remove))
print(G1.number_of_nodes(),G1.number_of_edges())
# Out:
# removed 26282  nodes
# 0 0

# %%
unique_edges, reciprocal_list = reciprocal_edges(G1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-28-c3a8745dad39> in <module>
# ----> 1 unique_edges, reciprocal_list = reciprocal_edges(G1)
#
# <ipython-input-3-c86f7ed0ca77> in reciprocal_edges(G)
#      17     reciprocal = len(reciprocal_list)
#      18
# ---> 19     print("reciprocal:", reciprocal,len(unique_edges),"reciprocity:",reciprocal/float(len(unique_edges)),reciprocal/float(len(unique_edges)+reciprocal))
#      20     return  unique_edges, reciprocal_list
#
# ZeroDivisionError: float division by zero

# %%
G1nodes = list(G1.nodes())
pos = nx.spring_layout(G1)

# %%
# subG = np.random.choice(G1nodes,400)
# k = G1.subgraph(subG)  
k =G1

plt.figure()
nx.draw_networkx(k, pos=pos,with_labels=False,node_size=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# nx.draw(G1)

# %% [markdown]
# ### Output on file

# %%
outfile = 'RD/'+outnet+'.dat'
# nx.write_weighted_edgelist(G, '../data/input/'+outnet+'.dat')
nx.write_weighted_edgelist(G, outfile)
print(outfile)
# Out:
# RD/facebook-wosn-wall.dat
