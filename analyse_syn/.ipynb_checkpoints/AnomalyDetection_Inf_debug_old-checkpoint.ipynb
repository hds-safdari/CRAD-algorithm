# %%
import numpy as np
import pandas as pd

import tools as tl
import AnomalyDetection as adet
import cv_functions as cvfun

import matplotlib.pyplot as plt
import networkx as nx
import importlib
import sktensor as skt
from sklearn import metrics
from sklearn.metrics import f1_score

import time_glob as gl
# %matplotlib inline

# %%
cmap = 'PuBuGn'

def expected_Aija(U,V,W):
    if W.ndim==1:
        M=np.einsum('ik,jk->ijk',U,V)
        M=np.einsum('ijk,k->ij',M,W)
    else:    
        M=np.einsum('ik,jq->ijkq',U,V)
        M=np.einsum('ijkq,kq->ij',M,W)
    return M

# %%
gl.timer.verbose = True
gl.timer.color = 'green'
gl.timer.print_details = False
gl.timer.print_sub = True
gl.printer.verboseness = True
gl.parallelize = False

# %%
# %matplotlib notebook

# %%
label = '500_3_20.0_0_0.3_False_0'
label = 'syn_'+label
# label = 'dutch2_6'

# %%
dir0 = '../data/input/'
dir1 = dir0 + 'synthetic/edge_anomalies/'
# dir1 = dir0

# %%
# # original parameters
theta = np.load(dir1+'theta_'+label.split('syn_')[-1]+'.npz',allow_pickle=True)
# # define some support files
np.savetxt("../data/input/u.dat", theta['u'], delimiter=" ")
np.savetxt("../data/input/v.dat", theta['v'], delimiter=" ")
# np.savetxt("../data/input/z.dat", theta['z'], delimiter=" ")

theta['mu'],theta['pi'],theta['u'].shape
# Out:
# (array(1.e-12), array(0.3), (500, 3))

# %%
importlib.reload(tl)
# Out:
# <module 'tools' from '/Users/hsafdari/Library/Mobile Documents/com~apple~CloudDocs/Documents/Dr_Caterina_de_Bacco/anomaly_detection/code_RD_CS/tools.py'>

# %%
network = dir1 +label+'.dat'

# network = '../data/input/'+label+'.dat'

A, B, B_T, data_T_vals = tl.import_data(network,header=0)
nodes = A[0].nodes()
pos = nx.spring_layout(A[0]) 
N = len(nodes)
L = B.shape[0]
K = theta['u'].shape[-1]
print(N)
# Out:
# ../data/input/synthetic/edge_anomalies/syn_500_3_20.0_0_0.3_False_0.dat shape: (5531, 3)
# Number of nodes = 500
# Number of layers = 1
# Number of edges and average degree in each layer:
# E[0] = 5396 - <k> = 21.584
# M[0] = 5396 - <k_weighted> = 21.584
# Reciprocity (intended as the proportion of bi-directional edges over the unordered pairs) = 0.0
# Reciprocity (considering the weights of the edges) = 1.0
# 500

# %% [markdown]
# ### Initializing near ground truth

# %%
# len(data_AtAtm1.vals),len(subs_nzp[0]),len(data_T_vals),len(data.nonzero()[0])

# %%
fold = 1
prng = np.random.RandomState(seed=10)
rseed = prng.randint(1000)
indices = cvfun.shuffle_indices_all_matrix(N, L, rseed=rseed)
mask = cvfun.extract_mask_kfold(indices, N, fold=fold, NFold=5)
np.count_nonzero(theta['z'][mask[0]])
# Out:
# 0

# %%
# mask_nz = np.load('../data/output/5-fold_cv/mask_f1_100_3_20.0_0.2_False_10.pkl',allow_pickle=True)
# mask = np.zeros_like(B).astype('int')
# mask[mask_nz] = 1

# %%
# np.allclose(mask,mask0)

# %%
B_train = B.copy()
B_train[mask > 0] = 0

# %%
importlib.reload(adet)
importlib.reload(tl)
# Out:
# <module 'tools' from '/Users/hsafdari/Library/Mobile Documents/com~apple~CloudDocs/Documents/Dr_Caterina_de_Bacco/anomaly_detection/code_RD_CS/tools.py'>

# %%
# %%time
flag_anomaly = True
mask_input = np.logical_not(mask)
mask_input = None 
model = adet.AnomalyDetection(plot_loglik=True,verbose = 1,initialization=0,K=K,N=N,N_real=1,  
                              undirected=False,fix_communities=False,flag_anomaly=flag_anomaly,
                              in_parameters=dir1+'theta_'+label.split('syn_')[-1],rseed=10,
                              fix_pibr=False, fix_mupr=False,bg=1.,out_inference=False,
                              end_file = label,constraintU=True,assortative=True,
                              weighted=True,pibr0=0, mupr0= 0)

u,v,w,pi,mu,maxL = model.fit(data=B_train,nodes=nodes,mask = mask_input) 

# print('\nInferred eta: {}\n'.format(out_dict['eta']))
print('\nInferred mu: {}, true mu: {}.\n'.format(mu,theta['mu']))
print('\nInferred pi: {}, true pi: {}.\n'.format(pi,theta['pi']))
# Out:
# Nreal = 0 - ELBO = -31996.6763441362 - ELBOmax = -31996.6763441362 - it = 7  time = 125.98 seconds
# conv: True 7 100
# ('fit: 126.129 seconds', 'green')
# ('    cache      : 0.020 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('                 QIJ: 0.019 seconds', 'green')(' (95%', 'green')(')', 'green')
# ('    em         : 15.128 seconds', 'green')(' (12%', 'green')(')', 'green')
# ('                 U            : 0.172 seconds', 'green')(' (1%', 'green')(')', 'green')
# ('                 cache        : 0.013 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('                                QIJ: 0.012 seconds', 'green')(' (91%', 'green')(')', 'green')
# ('                 V            : 0.168 seconds', 'green')(' (1%', 'green')(')', 'green')
# ('                 W_assortative: 0.002 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('                 convergence  : 0.010 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('                                ELBO: 0.010 seconds', 'green')(' (100%', 'green')(')', 'green')
# ('                 mupr         : 0.000 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('                 pibr         : 0.000 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('    convergence: 0.011 seconds', 'green')(' (0%', 'green')(')', 'green')
# ('                 ELBO: 0.010 seconds', 'green')(' (100%', 'green')(')', 'green')
#
#
# Inferred mu: 0.024418810028013046, true mu: 1e-12.
#
#
# Inferred pi: 0.013603455744961851, true pi: 0.3.
#
# CPU times: user 2min 5s, sys: 767 ms, total: 2min 5s
# Wall time: 2min 6s

# %% [markdown]
# ### AUC
# - $(A,\hat{A})$
# - $(Q,Z)$

# %%
importlib.reload(cvfun)
# Out:
# <module 'cv_functions' from '/Users/hsafdari/Library/Mobile Documents/com~apple~CloudDocs/Documents/Dr_Caterina_de_Bacco/anomaly_detection/code_RD_CS/cv_functions.py'>

# %%
M0 = cvfun._lambda0_full(u, v, w)
if flag_anomaly == False:
    Q = np.zeros_like(M0)
else:
    Q = cvfun.calculate_Q_dense(B,M0,pi,mu)
M = cvfun.calculate_expectation(u,v,w,Q[0],pi)

Q = cvfun.calculate_Q_dense(B,M0,pi,mu)

# %%
maskQ = np.logical_and(mask[0]>0,B[0]>0)
cvfun.calculate_AUC(M[0], B[0], mask=mask[0]),cvfun.calculate_AUC(Q[0], theta['z'], mask=maskQ)
# Out:
# /Users/hsafdari/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:1001: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning,
# (0.7952646142523729, nan)

# %%
f1 = cvfun.calculate_f1_score(Q,theta['z'], mask = maskQ)
f1
# Out:
# 0.0

# %% [markdown]
# ### Cosine Similarity

# %%
u1, cs_u = cvfun.cosine_similarity(u,theta['u'])
v1, cs_v = cvfun.cosine_similarity(v,theta['v'])
cs_u,cs_v
# Out:
# (0.98818152849146, 0.9897974888954736)

# %%
u1 = cvfun.normalize_nonzero_membership(u)
v1 = cvfun.normalize_nonzero_membership(v)
    
f1_u = cvfun.evalu(u1,theta['u'], 'f1')
f1_v = cvfun.evalu(v1,theta['v'], 'f1')
f1_u,f1_v
# Out:
# (0.998, 1.0)

# %% [markdown]
# ### Ground truth communities

# %%
umax=np.argmax(theta['u'],1)#max of each u
# plt.figure(figsize=(14,10))
nodelist = []
for k in range(K+1):
    nodelist.extend([i for i in range(N) if umax[i]==k])
    
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(14,10))
ax = axes.flatten()

nx.draw(A[0],pos=pos, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[0])
ax[0].set_axis_off()

umax=np.argmax(u,1)#max of each u

nx.draw(A[0],pos=pos, with_labels=True,node_color = umax,cmap = plt.cm.Set1,ax=ax[1])

plt.show()

# %% [markdown]
# ### A vs M

# %%
plt.figure(figsize=(14,8))
plt.subplot(1, 2, 1)
plt.imshow(B[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('A')
plt.subplot(1, 2, 2)
plt.imshow(M[0][nodelist][:,nodelist], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('<A>')
plt.show()

# %% [markdown]
# ### Q vs Z

# %%
threshold = 0.5
Z_pred = np.copy(Q[0])
Z_pred[Z_pred<threshold] = 0
Z_pred[Z_pred>=threshold] = 1

# %%
plt.figure(figsize=(16,10))  
plt.subplot(1, 3, 1)
plt.imshow(theta['z'], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('Z')
plt.subplot(1, 3, 2)
plt.imshow(Z_pred, cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('Z_pred')
plt.subplot(1, 3, 3)
plt.imshow(Q[0], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('Q')
plt.show()

# %% [markdown]
# ### W

# %%
plt.figure(figsize=(12,8))
plt.subplot(1, 2, 1)
plt.imshow(theta['w'], cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('w')
plt.subplot(1, 2, 2)
try:
    plt.imshow(w[0], cmap=cmap, interpolation='nearest')
except:
    plt.imshow(np.diag(w[0]), cmap=cmap, interpolation='nearest')
plt.colorbar(fraction=0.046)
plt.title('<w>')
plt.show()
